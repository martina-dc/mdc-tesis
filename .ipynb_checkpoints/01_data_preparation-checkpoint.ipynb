# %% [markdown]
# ## Data Preparation

# %%
import pandas as pd
import os
import json
import ast
import numpy as np
try:
    from pyprojroot import here
    print("Libreria: 'pyprojroot' esta instalada y se cargo correctamente")
except ModuleNotFoundError:
    print("Libreria: 'pyprojroot' no esta instalada, se debe instalar")
    # !pip install pyprojroot
    
import sys
sys.path.append(here())
from utils.utils import get_attributes_from_row
# Out:
# Libreria: 'pyprojroot' esta instalada y se cargo correctamente

# %%
here()
# Out:
# WindowsPath('C:/Users/marti/OneDrive/Escritorio/Tesis/mdc-tesis')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
path = here() / "data"

# %%
df = pd.read_csv(path / "datos_laptops.csv", sep = ';')

# %%
df.head()
# Out:
#               id site_id                                              title  \
# 0  MLA1151530200     MLA  Notebook Lenovo Ideapad 3 14iil05 Intel Core I...
# 1  MLA1149134293     MLA  Notebook Lenovo Ideapad 14iil05  Platinum Gray...
# 2  MLA1135443731     MLA  Notebook Exo Smart L33e Gris 14 , Intel Celero...
# 3   MLA913506600     MLA  Notebook Banghó Max L4 I1 Gris Oscura 14 , Int...
# 4  MLA1138721902     MLA  Notebook Hp 14-dq2029la Plata Natural 14 , Int...
#
#    subtitle   seller_id category_id  official_store_id        price  \
# 0       NaN   174556876     MLA1652                NaN  89999.00000
# 1       NaN   335450469     MLA1652          455.00000 132616.00000
# 2       NaN    25704919     MLA1652                NaN  59999.00000
# 3       NaN    31875925     MLA1652                NaN  71999.00000
# 4       NaN  1006692747     MLA1652          317.00000 139999.00000
#
#     base_price  original_price currency_id  initial_quantity  \
# 0  89999.00000     94999.00000         ARS               105
# 1 132616.00000             NaN         ARS                75
# 2  59999.00000     64999.00000         ARS               482
# 3  71999.00000             NaN         ARS              9979
# 4 139999.00000    151999.00000         ARS               339
#
#    available_quantity  sold_quantity  \
# 0                   1             50
# 1                   1             50
# 2                   1            250
# 3                5000            500
# 4                   1            250
#
#                                           sale_terms buying_mode  \
# 0  [{'id': 'WARRANTY_TYPE', 'name': 'Tipo de gara...  buy_it_now
# 1  [{'id': 'WARRANTY_TYPE', 'name': 'Tipo de gara...  buy_it_now
# 2  [{'id': 'INVOICE', 'name': 'Facturación', 'val...  buy_it_now
# 3  [{'id': 'WARRANTY_TYPE', 'name': 'Tipo de gara...  buy_it_now
# 4  [{'id': 'WARRANTY_TYPE', 'name': 'Tipo de gara...  buy_it_now
#
#   listing_type_id                start_time                 stop_time  \
# 0    gold_special  2022-08-11T16:12:19.000Z  2042-08-06T04:00:00.000Z
# 1    gold_special  2022-08-01T19:07:12.000Z  2042-07-27T04:00:00.000Z
# 2    gold_special  2022-05-04T15:42:37.000Z  2042-04-29T04:00:00.000Z
# 3    gold_special  2021-03-25T22:07:13.000Z  2041-03-20T04:00:00.000Z
# 4    gold_special  2022-05-24T18:58:44.000Z  2042-07-06T19:39:16.000Z
#
#   condition                                          permalink  \
# 0       new  https://articulo.mercadolibre.com.ar/MLA-11515...
# 1       new  https://articulo.mercadolibre.com.ar/MLA-11491...
# 2       new  https://articulo.mercadolibre.com.ar/MLA-11354...
# 3       new  https://articulo.mercadolibre.com.ar/MLA-91350...
# 4       new  https://articulo.mercadolibre.com.ar/MLA-11387...
#
#                    thumbnail_id  \
# 0  975834-MLA51015201380_082022
# 1  879170-MLA45629747467_042021
# 2  895255-MLA48454315654_122021
# 3  925102-MLA44939831146_022021
# 4  942069-MLA49250542587_032022
#
#                                            thumbnail  \
# 0  http://http2.mlstatic.com/D_975834-MLA51015201...
# 1  http://http2.mlstatic.com/D_879170-MLA45629747...
# 2  http://http2.mlstatic.com/D_895255-MLA48454315...
# 3  http://http2.mlstatic.com/D_925102-MLA44939831...
# 4  http://http2.mlstatic.com/D_942069-MLA49250542...
#
#                                     secure_thumbnail  \
# 0  https://http2.mlstatic.com/D_975834-MLA5101520...
# 1  https://http2.mlstatic.com/D_879170-MLA4562974...
# 2  https://http2.mlstatic.com/D_895255-MLA4845431...
# 3  https://http2.mlstatic.com/D_925102-MLA4493983...
# 4  https://http2.mlstatic.com/D_942069-MLA4925054...
#
#                                             pictures video_id descriptions  \
# 0  [{'id': '975834-MLA51015201380_082022', 'url':...      NaN           []
# 1  [{'id': '879170-MLA45629747467_042021', 'url':...      NaN           []
# 2  [{'id': '895255-MLA48454315654_122021', 'url':...      NaN           []
# 3  [{'id': '925102-MLA44939831146_022021', 'url':...      NaN           []
# 4  [{'id': '942069-MLA49250542587_032022', 'url':...      NaN           []
#
#    accepts_mercadopago non_mercado_pago_payment_methods  \
# 0                 True                               []
# 1                 True                               []
# 2                 True                               []
# 3                 True                               []
# 4                 True                               []
#
#   international_delivery_mode  seller_contact coverage_areas  \
# 0                        none             NaN             []
# 1                        none             NaN             []
# 2                        none             NaN             []
# 3                        none             NaN             []
# 4                        none             NaN             []
#
#                                           attributes warnings  listing_source  \
# 0  [{'id': 'BATTERY_TYPE', 'name': 'Tipo de bater...       []             NaN
# 1  [{'id': 'ALPHANUMERIC_MODEL', 'name': 'Modelo ...       []             NaN
# 2  [{'id': 'ASPECT_RATIO', 'name': 'Relación de a...       []             NaN
# 3  [{'id': 'GPU', 'name': 'GPU', 'value_id': '301...       []             NaN
# 4  [{'id': 'ASPECT_RATIO', 'name': 'Relación de a...       []             NaN
#
#   variations  status sub_status  \
# 0         []  active         []
# 1         []  active         []
# 2         []  active         []
# 3         []  active         []
# 4         []  active         []
#
#                                                 tags  \
# 0  ['good_quality_thumbnail', 'standard_price_by_...
# 1  ['extended_warranty_eligible', 'good_quality_p...
# 2  ['extended_warranty_eligible', 'good_quality_p...
# 3  ['extended_warranty_eligible', 'good_quality_p...
# 4  ['extended_warranty_eligible', 'good_quality_p...
#
#                          warranty catalog_product_id      domain_id  \
# 0   Garantía de fábrica: 12 meses        MLA19525764  MLA-NOTEBOOKS
# 1  Garantía del vendedor: 6 meses        MLA17796660  MLA-NOTEBOOKS
# 2   Garantía de fábrica: 12 meses        MLA18330430  MLA-NOTEBOOKS
# 3     Garantía de fábrica: 1 años        MLA16273683  MLA-NOTEBOOKS
# 4   Garantía de fábrica: 12 meses        MLA18953578  MLA-NOTEBOOKS
#
#   parent_item_id  differential_pricing                           deal_ids  \
# 0            NaN                   NaN                        ['MLA6015']
# 1            NaN                   NaN                                 []
# 2            NaN                   NaN  ['MLA8258', 'MLA9166', 'MLA6015']
# 3            NaN                   NaN                        ['MLA8755']
# 4            NaN                   NaN            ['MLA8258', 'MLA11620']
#
#    automatic_relist              date_created              last_updated  \
# 0             False  2022-08-11T16:12:19.000Z  2022-08-23T21:01:04.541Z
# 1             False  2022-08-01T19:07:12.000Z  2022-08-23T18:47:54.130Z
# 2             False  2022-05-04T15:42:38.000Z  2022-08-23T19:02:35.808Z
# 3             False  2021-03-25T22:07:13.000Z  2022-08-23T12:07:29.201Z
# 4             False  2022-05-24T18:58:45.000Z  2022-08-23T20:14:23.469Z
#
#    health  catalog_listing                   channels shipping.mode  \
# 0     NaN             True            ['marketplace']           me2
# 1     NaN             True  ['marketplace', 'mshops']           me2
# 2     NaN             True  ['marketplace', 'mshops']           me2
# 3     NaN             True  ['marketplace', 'mshops']           me2
# 4     NaN             True            ['marketplace']           me2
#
#   shipping.methods                                   shipping.tags  \
# 0               []  ['self_service_in', 'mandatory_free_shipping']
# 1               []  ['self_service_in', 'mandatory_free_shipping']
# 2               []  ['self_service_in', 'mandatory_free_shipping']
# 3               []  ['self_service_in', 'mandatory_free_shipping']
# 4               []  ['self_service_in', 'mandatory_free_shipping']
#
#    shipping.dimensions  shipping.local_pick_up  shipping.free_shipping  \
# 0                  NaN                    True                    True
# 1                  NaN                    True                    True
# 2                  NaN                    True                    True
# 3                  NaN                    True                    True
# 4                  NaN                    True                    True
#
#   shipping.logistic_type  shipping.store_pick_up seller_address.city.id  \
# 0          cross_docking                   False       TUxBQlZJTDQyMjBa
# 1          cross_docking                   False       TUxBQkJFTDcyNTJa
# 2          cross_docking                   False       TUxBQlNBTjgzMjRa
# 3          cross_docking                   False       TUxBQlZJTDcwOTla
# 4          cross_docking                   False       TUxBQlBBUjYwMzZa
#
#   seller_address.city.name seller_address.state.id seller_address.state.name  \
# 0             Villa Crespo                    AR-C           Capital Federal
# 1                 Belgrano                    AR-C           Capital Federal
# 2              San Nicolás                    AR-C           Capital Federal
# 3            Villa Urquiza                    AR-C           Capital Federal
# 4         Parque Patricios                    AR-C           Capital Federal
#
#   seller_address.country.id seller_address.country.name  \
# 0                        AR                   Argentina
# 1                        AR                   Argentina
# 2                        AR                   Argentina
# 3                        AR                   Argentina
# 4                        AR                   Argentina
#
#   seller_address.search_location.neighborhood.id  \
# 0                               TUxBQlZJTDQyMjBa
# 1                               TUxBQkJFTDcyNTJa
# 2                               TUxBQlNBTjgzMjRa
# 3                               TUxBQlZJTDcwOTla
# 4                               TUxBQlBBUjYwMzZa
#
#   seller_address.search_location.neighborhood.name  \
# 0                                     Villa Crespo
# 1                                         Belgrano
# 2                                      San Nicolás
# 3                                    Villa Urquiza
# 4                                 Parque Patricios
#
#   seller_address.search_location.city.id  \
# 0                     TUxBQ0NBUGZlZG1sYQ
# 1                     TUxBQ0NBUGZlZG1sYQ
# 2                     TUxBQ0NBUGZlZG1sYQ
# 3                     TUxBQ0NBUGZlZG1sYQ
# 4                     TUxBQ0NBUGZlZG1sYQ
#
#   seller_address.search_location.city.name  \
# 0                          Capital Federal
# 1                          Capital Federal
# 2                          Capital Federal
# 3                          Capital Federal
# 4                          Capital Federal
#
#   seller_address.search_location.state.id  \
# 0                        TUxBUENBUGw3M2E1
# 1                        TUxBUENBUGw3M2E1
# 2                        TUxBUENBUGw3M2E1
# 3                        TUxBUENBUGw3M2E1
# 4                        TUxBUENBUGw3M2E1
#
#   seller_address.search_location.state.name  seller_address.id  \
# 0                           Capital Federal          155782338
# 1                           Capital Federal          977722220
# 2                           Capital Federal         1082076973
# 3                           Capital Federal         1174670649
# 4                           Capital Federal         1198381035
#
#   shipping.free_methods installment display_size shipping_cost
# 0                   NaN         yes   hasta 14.1          free
# 1                   NaN         yes   hasta 14.1          free
# 2                   NaN         yes   hasta 14.1          free
# 3                   NaN         yes   hasta 14.1          free
# 4                   NaN         yes   hasta 14.1          free

# %%
df.describe()
# Out:
#        subtitle        seller_id  official_store_id         price  \
# count   0.00000      11579.00000          505.00000   11579.00000
# mean        NaN  241854386.05700          902.05347  206447.19241
# std         NaN  244180365.79441          881.07513  125019.73030
# min         NaN      60389.00000           56.00000    4200.00000
# 25%         NaN   69526727.00000           82.00000  148773.87500
# 50%         NaN  131648529.00000          341.00000  189999.00000
# 75%         NaN  309453406.00000         1466.00000  232499.00000
# max         NaN 1184828893.00000         2846.00000 2701999.00000
#
#          base_price  original_price  initial_quantity  available_quantity  \
# count   11579.00000      1859.00000       11579.00000         11579.00000
# mean   206447.19241    242433.40545         761.90163           374.51740
# std    125019.73030    103461.64742        2518.57527          1258.84574
# min      4200.00000     46788.00000           1.00000             1.00000
# 25%    148773.87500    178654.00000           3.00000             1.00000
# 50%    189999.00000    233995.00000          10.00000             1.00000
# 75%    232499.00000    292199.00000          42.00000             1.00000
# max   2701999.00000   1432445.00000       10336.00000          5000.00000
#
#        sold_quantity  seller_contact  listing_source  differential_pricing  \
# count    11579.00000         0.00000         0.00000               0.00000
# mean         4.55445             NaN             NaN                   NaN
# std         28.93319             NaN             NaN                   NaN
# min          0.00000             NaN             NaN                   NaN
# 25%          0.00000             NaN             NaN                   NaN
# 50%          0.00000             NaN             NaN                   NaN
# 75%          1.00000             NaN             NaN                   NaN
# max        500.00000             NaN             NaN                   NaN
#
#            health  shipping.dimensions  seller_address.id
# count 11187.00000              0.00000        11579.00000
# mean      0.84086                  NaN    873472942.74540
# std       0.14211                  NaN    428098763.50951
# min       0.50000                  NaN       517930.00000
# 25%       0.77000                  NaN    434380000.00000
# 50%       0.90000                  NaN   1128845189.00000
# 75%       1.00000                  NaN   1174670649.00000
# max       1.00000                  NaN   1250848391.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11579 entries, 0 to 11578
# Data columns (total 76 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   id                                                11579 non-null  object
#  1   site_id                                           11579 non-null  object
#  2   title                                             11579 non-null  object
#  3   subtitle                                          0 non-null      float64
#  4   seller_id                                         11579 non-null  int64
#  5   category_id                                       11579 non-null  object
#  6   official_store_id                                 505 non-null    float64
#  7   price                                             11579 non-null  float64
#  8   base_price                                        11579 non-null  float64
#  9   original_price                                    1859 non-null   float64
#  10  currency_id                                       11579 non-null  object
#  11  initial_quantity                                  11579 non-null  int64
#  12  available_quantity                                11579 non-null  int64
#  13  sold_quantity                                     11579 non-null  int64
#  14  sale_terms                                        11579 non-null  object
#  15  buying_mode                                       11579 non-null  object
#  16  listing_type_id                                   11579 non-null  object
#  17  start_time                                        11579 non-null  object
#  18  stop_time                                         11579 non-null  object
#  19  condition                                         11579 non-null  object
#  20  permalink                                         11579 non-null  object
#  21  thumbnail_id                                      11579 non-null  object
#  22  thumbnail                                         11579 non-null  object
#  23  secure_thumbnail                                  11579 non-null  object
#  24  pictures                                          11579 non-null  object
#  25  video_id                                          564 non-null    object
#  26  descriptions                                      11579 non-null  object
#  27  accepts_mercadopago                               11579 non-null  bool
#  28  non_mercado_pago_payment_methods                  11579 non-null  object
#  29  international_delivery_mode                       11579 non-null  object
#  30  seller_contact                                    0 non-null      float64
#  31  coverage_areas                                    11579 non-null  object
#  32  attributes                                        11579 non-null  object
#  33  warnings                                          11579 non-null  object
#  34  listing_source                                    0 non-null      float64
#  35  variations                                        11579 non-null  object
#  36  status                                            11579 non-null  object
#  37  sub_status                                        11579 non-null  object
#  38  tags                                              11579 non-null  object
#  39  warranty                                          11224 non-null  object
#  40  catalog_product_id                                6078 non-null   object
#  41  domain_id                                         11579 non-null  object
#  42  parent_item_id                                    57 non-null     object
#  43  differential_pricing                              0 non-null      float64
#  44  deal_ids                                          11579 non-null  object
#  45  automatic_relist                                  11579 non-null  bool
#  46  date_created                                      11579 non-null  object
#  47  last_updated                                      11579 non-null  object
#  48  health                                            11187 non-null  float64
#  49  catalog_listing                                   11579 non-null  bool
#  50  channels                                          11579 non-null  object
#  51  shipping.mode                                     11579 non-null  object
#  52  shipping.methods                                  9597 non-null   object
#  53  shipping.tags                                     11579 non-null  object
#  54  shipping.dimensions                               0 non-null      float64
#  55  shipping.local_pick_up                            11579 non-null  bool
#  56  shipping.free_shipping                            11579 non-null  bool
#  57  shipping.logistic_type                            11579 non-null  object
#  58  shipping.store_pick_up                            11579 non-null  bool
#  59  seller_address.city.id                            9718 non-null   object
#  60  seller_address.city.name                          11579 non-null  object
#  61  seller_address.state.id                           11579 non-null  object
#  62  seller_address.state.name                         11579 non-null  object
#  63  seller_address.country.id                         11579 non-null  object
#  64  seller_address.country.name                       11579 non-null  object
#  65  seller_address.search_location.neighborhood.id    10442 non-null  object
#  66  seller_address.search_location.neighborhood.name  10438 non-null  object
#  67  seller_address.search_location.city.id            11477 non-null  object
#  68  seller_address.search_location.city.name          11473 non-null  object
#  69  seller_address.search_location.state.id           11512 non-null  object
#  70  seller_address.search_location.state.name         11508 non-null  object
#  71  seller_address.id                                 11579 non-null  int64
#  72  shipping.free_methods                             1982 non-null   object
#  73  installment                                       11579 non-null  object
#  74  display_size                                      11579 non-null  object
#  75  shipping_cost                                     11579 non-null  object
# dtypes: bool(6), float64(10), int64(5), object(55)
# memory usage: 6.3+ MB

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (11576, 76)

# %% [markdown]
# # Seleccionamos las columnas de interes

# %%
selected_cols = ["id", "title","seller_id","price","base_price","deal_ids","initial_quantity","sold_quantity", "listing_type_id",
                 "available_quantity","sold_quantity","sale_terms","condition", "installment", "display_size", "shipping_cost",
                 "descriptions","attributes","warnings","status","date_created","shipping.mode","shipping.free_shipping"]

df = df[selected_cols]

# %%
df.status.value_counts()
# Out:
# active    11574
# paused        2
# Name: status, dtype: int64

# %% [markdown]
# #### Filtramos aquellas que no esten activas

# %%
c_active = df.status.isin(["active"])
df = df[c_active]

# %%
df["shipping.mode"].value_counts()
# Out:
# me2              11573
# not_specified        1
# Name: shipping.mode, dtype: int64

# %%
df["shipping.free_shipping"].value_counts()
# Out:
# True     11573
# False        1
# Name: shipping.free_shipping, dtype: int64

# %%
df["listing_type_id"].value_counts()
# Out:
# gold_special    6079
# gold_pro        5455
# free              40
# Name: listing_type_id, dtype: int64

# %% [markdown]
# #### Borramos del df original aquellas que tengan mas del 50% nulos

# %%
perc = 50.0 # Like N %
min_count =  int(((100-perc)/100)*df.shape[0] + 1)
df = df.dropna( axis=1, 
                thresh=min_count)
df.info(verbose = True, show_counts  = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11574 entries, 0 to 11578
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      11574 non-null  object
#  1   title                   11574 non-null  object
#  2   seller_id               11574 non-null  int64
#  3   price                   11574 non-null  float64
#  4   base_price              11574 non-null  float64
#  5   deal_ids                11574 non-null  object
#  6   initial_quantity        11574 non-null  int64
#  7   sold_quantity           11574 non-null  int64
#  8   listing_type_id         11574 non-null  object
#  9   available_quantity      11574 non-null  int64
#  10  sold_quantity           11574 non-null  int64
#  11  sale_terms              11574 non-null  object
#  12  condition               11574 non-null  object
#  13  installment             11574 non-null  object
#  14  display_size            11574 non-null  object
#  15  shipping_cost           11574 non-null  object
#  16  descriptions            11574 non-null  object
#  17  attributes              11574 non-null  object
#  18  warnings                11574 non-null  object
#  19  status                  11574 non-null  object
#  20  date_created            11574 non-null  object
#  21  shipping.mode           11574 non-null  object
#  22  shipping.free_shipping  11574 non-null  bool
# dtypes: bool(1), float64(2), int64(5), object(15)
# memory usage: 2.0+ MB

# %% [markdown]
# ## Desarmamos las columnas attributes y sale_terms que son un dicc

# %%
df_attributes = df[["id","attributes"]].copy()
dummy = df_attributes["attributes"].apply(lambda x: ast.literal_eval(x))

df_sale_terms = df[["id","sale_terms"]].copy()
dummy_st = df_sale_terms["sale_terms"].apply(lambda x: ast.literal_eval(x))

# %%
lista_filas = []
lista_id = []
for (index_dummy, row), (index_df, rowa) in zip(pd.DataFrame(dummy).iterrows(), df_attributes.iterrows()):
    lista_filas.append(get_attributes_from_row(row))
    lista_id.append(rowa['id'])

lista_filas_st = []
lista_id_st = []
for (index_dummy, row), (index_df, rowa) in zip(pd.DataFrame(dummy_st).iterrows(), df_sale_terms.iterrows()):
    lista_filas_st.append(get_attributes_from_row(row))
    lista_id_st.append(rowa['id'])

# %%
for df1, df2 in zip(lista_filas, lista_id):
    df1["id"] = df2

df_attributes = pd.concat(lista_filas)
display(df_attributes.head())
# Out:
#      Tipo de batería   Marca          Color Cantidad de núcleos  \
# 0       Ion de litio  Lenovo   Gris platino                   2
# 0  Polímero de litio  Lenovo  Platinum gray                   4
# 0                NaN     EXO           Gris                   2
# 0       Ion de litio  Banghó    Gris oscuro                   2
# 0       Ion de litio      HP  Plata natural                   4
#
#   Modelo detallado Frecuencia de actualización de la pantalla  \
# 0       81WD010UUS                                      60 Hz
# 0       81WD00U9US                                        NaN
# 0              NaN                                        NaN
# 0              NaN                                      60 Hz
# 0          3V8K0LA                                      60 Hz
#
#   Resolución de la pantalla Tipo de resolución de la pantalla   \
# 0         1920 px x 1080 px                            Full HD
# 0         1920 px x 1080 px                            Full HD
# 0          1366 px x 768 px                                 HD
# 0          1366 px x 768 px                                 HD
# 0          1366 px x 768 px                                 HD
#
#   Tamaño de la pantalla Tipo de pantalla Canal exclusivo  \
# 0                  14 "              LCD   Mercado Libre
# 0                  14 "              LCD             NaN
# 0                  14 "              LED             NaN
# 0                  14 "              LCD             NaN
# 0                  14 "              NaN             NaN
#
#                    Tarjeta gráfica Es 2 en 1 Es gamer Es ultrabook  \
# 0               Intel UHD Graphics        No       No           No
# 0            Intel UHD Graphics G1       NaN      NaN          NaN
# 0           Intel UHD Graphics 600       NaN      NaN          NaN
# 0           Intel UHD Graphics 600        No       No           No
# 0  Intel Iris Xe Graphics G7 80EUs        No       No           No
#
#   Condición del ítem Idioma del teclado       Línea Color principal  \
# 0              Nuevo             Inglés   IDEAPAD 3            Gris
# 0              Nuevo                NaN     IdeaPad        Plateado
# 0              Nuevo                NaN       Smart            Gris
# 0              Nuevo                NaN         Max            Gris
# 0              Nuevo                NaN  Intel Core        Plateado
#
#   Capacidad máxima soportada de la memoria RAM       Modelo  \
# 0                                        12 GB      14IIL05
# 0                                        12 GB            3
# 0                                          NaN         L33E
# 0                                          NaN        L4 i1
# 0                                          NaN  14-dq2029la
#
#   Edición del sistema operativo Nombre del sistema operativo  \
# 0                             S                      Windows
# 0                          Home                      Windows
# 0                          Home                      Windows
# 0                          Home                      Windows
# 0                          Home                      Windows
#
#   Versión del sistema operativo Tipo de panel Marca del procesador  \
# 0                            11            TN                Intel
# 0                            10           NaN                Intel
# 0                            10           NaN                Intel
# 0                            10           NaN                Intel
# 0                            10           NaN                Intel
#
#   Línea del procesador Modelo del procesador Memoria RAM Tipo de memoria RAM  \
# 0              Core i3                1005G1        8 GB                DDR4
# 0              Core i5                1035G1        8 GB                DDR4
# 0              Celeron                 N4020        4 GB                DDR4
# 0              Celeron                 N4000        4 GB                DDR4
# 0              Core i5                1135G7        8 GB                DDR4
#
#   Cantidad de ranuras para la memoria RAM          SKU Capacidad del SSD  \
# 0                                       1  160012096.1            128 GB
# 0                                       2   81WA00Q7US            512 GB
# 0                                     NaN    EXO000016             64 GB
# 0                                     NaN          NaN            120 GB
# 0                                       2        56299            256 GB
#
#   Interfaz del SSD Cantidad total de puertos USB  \
# 0             PCIe                             3
# 0             PCIe                             3
# 0              NaN                             2
# 0              NaN                             3
# 0             PCIe                             3
#
#   Tipo de resolución de video de la cámara web     Peso  \
# 0                                         720p   1.6 kg
# 0                                          NaN   1.6 kg
# 0                                           HD   1350 g
# 0                                          NaN   1.3 kg
# 0                                           HD  1.46 kg
#
#   Con teclado retroiluminado Con Bluetooth Con puerto ethernet  \
# 0                         No            Sí                  No
# 0                         No            Sí                  No
# 0                        NaN            Sí                 NaN
# 0                        NaN            Sí                  No
# 0                        NaN            Sí                 NaN
#
#   Con lector de huella digital Con HDMI Con salida para auriculares  \
# 0                           No       Sí                          Sí
# 0                           No       Sí                          Sí
# 0                          NaN       Sí                          Sí
# 0                          NaN       Sí                          Sí
# 0                          NaN       Sí                          Sí
#
#   Con lector de tarjeta de memoria Con micrófono Con pad numérico  \
# 0                               Sí            Sí               No
# 0                               Sí            Sí              NaN
# 0                               Sí            Sí              NaN
# 0                               Sí            Sí              NaN
# 0                               Sí            Sí              NaN
#
#   Con pantalla retina Con pantalla táctil Con cámara web Con Wi-Fi  \
# 0                  No                  No             Sí        Sí
# 0                 NaN                  No             Sí        Sí
# 0                 NaN                 NaN             Sí        Sí
# 0                  No                  No             Sí        Sí
# 0                 NaN                  No             Sí        Sí
#
#               id Modelo alfanumérico Relación de aspecto  \
# 0  MLA1151530200                 NaN                 NaN
# 0  MLA1149134293             14IIL05                16:9
# 0  MLA1135443731                 NaN                16:9
# 0   MLA913506600                 NaN                16:9
# 0  MLA1138721902                 NaN                16:9
#
#   Duración de la batería Profundidad Código universal de producto  \
# 0                    NaN         NaN                          NaN
# 0                  7.7 h      241 mm                0196119591499
# 0                    NaN      216 mm                7797678016879
# 0                    NaN    219.5 mm                7798346200477
# 0                 11.3 h     22.5 cm                 195908557715
#
#   Capacidad del disco rígido   Altura Velocidad máxima del procesador  \
# 0                        NaN      NaN                             NaN
# 0                       1 TB  19.9 mm                         3.6 GHz
# 0                        NaN  22.2 mm                         2.8 GHz
# 0                       None  18.3 mm                         2.6 GHz
# 0                        NaN  1.79 cm                         4.2 GHz
#
#           MPN Velocidad de la memoria RAM     Modos de sonido  \
# 0         NaN                         NaN                 NaN
# 0  81WD00U9US                    2666 MHz  Dolby Audio,Stereo
# 0         NaN                         NaN                 NaN
# 0         NaN                    2400 MHz              Stereo
# 0     3V8K0LA                    2666 MHz              Stereo
#
#   Cantidad de parlantes Puertos USB Puertos de video  \
# 0                   NaN         NaN              NaN
# 0                     2     2.0,3.2             HDMI
# 0                   NaN     2.0,3.0        Mini-HDMI
# 0                     2   2.0,3.1,C             HDMI
# 0                     2   A3.0,C3.0             HDMI
#
#   Resolución de la imagen fija de la cámara web     Ancho  \
# 0                                           NaN       NaN
# 0                                       0.3 Mpx  327.1 mm
# 0                                         2 Mpx    327 mm
# 0                                         1 Mpx  324.9 mm
# 0                                           NaN   32.4 cm
#
#   Con pantalla antirreflejo Con USB Velocidad mínima del procesador  \
# 0                       NaN     NaN                             NaN
# 0                        Sí      Sí                             NaN
# 0                       NaN      Sí                         1.1 GHz
# 0                       NaN      Sí                             NaN
# 0                       NaN      Sí                         2.4 GHz
#
#                      GPU Capacidad Optane Unidades ópticas Memoria de video  \
# 0                    NaN              NaN              NaN              NaN
# 0                    NaN              NaN              NaN              NaN
# 0                    NaN              NaN              NaN              NaN
# 0  Intel HD Graphics 600             None             None             None
# 0                    NaN              NaN               No              NaN
#
#   Gama de colores                                 Software incluidos  \
# 0             NaN                                                NaN
# 0             NaN                                                NaN
# 0             NaN                                                NaN
# 0             NaN                                                NaN
# 0        45% NTSC  HP Connection Optimizer,HP Audio Switch,Protec...
#
#   Resolución de video de la cámara web Incluye lápiz Altura del paquete  \
# 0                                  NaN           NaN                NaN
# 0                                  NaN           NaN                NaN
# 0                                  NaN           NaN                NaN
# 0                                  NaN           NaN                NaN
# 0                     1280 px x 720 px           NaN                NaN
#
#   Largo del paquete Peso del paquete Ancho del paquete Embalaje del envío  \
# 0               NaN              NaN               NaN                NaN
# 0               NaN              NaN               NaN                NaN
# 0               NaN              NaN               NaN                NaN
# 0               NaN              NaN               NaN                NaN
# 0               NaN              NaN               NaN                NaN
#
#   Interfaz del disco rígido Velocidad del procesador  \
# 0                       NaN                      NaN
# 0                       NaN                      NaN
# 0                       NaN                      NaN
# 0                       NaN                      NaN
# 0                       NaN                      NaN
#
#   Información adicional requerida Características de las baterías  \
# 0                             NaN                             NaN
# 0                             NaN                             NaN
# 0                             NaN                             NaN
# 0                             NaN                             NaN
# 0                             NaN                             NaN
#
#   Características del producto Accesorios incluidos Tipo de resolución  \
# 0                          NaN                  NaN                NaN
# 0                          NaN                  NaN                NaN
# 0                          NaN                  NaN                NaN
# 0                          NaN                  NaN                NaN
# 0                          NaN                  NaN                NaN
#
#   Tipos de memoria de video Resolución de la cámara web Es kit Largo  \
# 0                       NaN                         NaN    NaN   NaN
# 0                       NaN                         NaN    NaN   NaN
# 0                       NaN                         NaN    NaN   NaN
# 0                       NaN                         NaN    NaN   NaN
# 0                       NaN                         NaN    NaN   NaN
#
#   Tipo de almacenamiento de datos Serie Capacidad de almacenamiento  \
# 0                             NaN   NaN                         NaN
# 0                             NaN   NaN                         NaN
# 0                             NaN   NaN                         NaN
# 0                             NaN   NaN                         NaN
# 0                             NaN   NaN                         NaN
#
#   Tags descriptivos Características químicas del producto Procesador  \
# 0               NaN                                   NaN        NaN
# 0               NaN                                   NaN        NaN
# 0               NaN                                   NaN        NaN
# 0               NaN                                   NaN        NaN
# 0               NaN                                   NaN        NaN
#
#   Disponibilidad de stock Fuente del producto Máxima capacidad de RAM  \
# 0                     NaN                 NaN                     NaN
# 0                     NaN                 NaN                     NaN
# 0                     NaN                 NaN                     NaN
# 0                     NaN                 NaN                     NaN
# 0                     NaN                 NaN                     NaN
#
#   Número de pieza
# 0             NaN
# 0             NaN
# 0             NaN
# 0             NaN
# 0             NaN

# %% [markdown]
# #### Borramos aquellas columnas del df de atributtes que tengan mas del 50% de nulos

# %%
perc = 50.0 # Like N %
min_count =  int(((100-perc)/100)*df_attributes.shape[0] + 1)
df_attributes = df_attributes.dropna( axis=1, 
                thresh=min_count)
df_attributes.info(verbose = True, null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11574 entries, 0 to 0
# Data columns (total 40 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Tipo de batería                   9644 non-null   object
#  1   Marca                             11574 non-null  object
#  2   Cantidad de núcleos               8495 non-null   object
#  3   Resolución de la pantalla         9824 non-null   object
#  4   Tamaño de la pantalla             11574 non-null  object
#  5   Tipo de pantalla                  5838 non-null   object
#  6   Tarjeta gráfica                   8228 non-null   object
#  7   Es 2 en 1                         9152 non-null   object
#  8   Es gamer                          9032 non-null   object
#  9   Es ultrabook                      8843 non-null   object
#  10  Condición del ítem                11574 non-null  object
#  11  Línea                             11200 non-null  object
#  12  Modelo                            11574 non-null  object
#  13  Edición del sistema operativo     7342 non-null   object
#  14  Nombre del sistema operativo      11574 non-null  object
#  15  Versión del sistema operativo     8071 non-null   object
#  16  Marca del procesador              11573 non-null  object
#  17  Línea del procesador              9755 non-null   object
#  18  Memoria RAM                       10002 non-null  object
#  19  Tipo de memoria RAM               10246 non-null  object
#  20  Capacidad del SSD                 9300 non-null   object
#  21  Cantidad total de puertos USB     7074 non-null   object
#  22  Peso                              10196 non-null  object
#  23  Con Bluetooth                     10036 non-null  object
#  24  Con puerto ethernet               5794 non-null   object
#  25  Con HDMI                          9491 non-null   object
#  26  Con salida para auriculares       7062 non-null   object
#  27  Con lector de tarjeta de memoria  5897 non-null   object
#  28  Con micrófono                     8944 non-null   object
#  29  Con pantalla táctil               9396 non-null   object
#  30  Con cámara web                    9137 non-null   object
#  31  Con Wi-Fi                         9676 non-null   object
#  32  id                                11574 non-null  object
#  33  Profundidad                       7434 non-null   object
#  34  Altura                            7367 non-null   object
#  35  Modos de sonido                   6110 non-null   object
#  36  Puertos USB                       6984 non-null   object
#  37  Puertos de video                  7080 non-null   object
#  38  Ancho                             7500 non-null   object
#  39  Con USB                           10080 non-null  object
# dtypes: object(40)
# memory usage: 3.6+ MB
# C:\Users\marti\AppData\Local\Temp\ipykernel_12548\4138409733.py:5: FutureWarning: null_counts is deprecated. Use show_counts instead
#   df_attributes.info(verbose = True, null_counts = True)

# %% [markdown]
# #### Garantia del producto

# %%
for df3, df4 in zip(lista_filas_st, lista_id_st):
    df3["id"] = df4

df_st = pd.concat(lista_filas_st)
df_st.head()
# Out:
#         Tipo de garantía Facturación Tiempo de garantía             id  \
# 0    Garantía de fábrica   Factura A           12 meses  MLA1151530200
# 0  Garantía del vendedor   Factura A            6 meses  MLA1149134293
# 0    Garantía de fábrica   Factura A           12 meses  MLA1135443731
# 0    Garantía de fábrica   Factura A             1 años   MLA913506600
# 0    Garantía de fábrica   Factura A           12 meses  MLA1138721902
#
#   Disponibilidad de stock Cantidad máxima de compra
# 0                     NaN                       NaN
# 0                     NaN                       NaN
# 0                     NaN                       NaN
# 0                     NaN                       NaN
# 0                     NaN                       NaN

# %%
del df_st["Cantidad máxima de compra"], df_st["Disponibilidad de stock"], df_st["Facturación"]

# %%
df_st.head()
# Out:
#         Tipo de garantía Tiempo de garantía             id
# 0    Garantía de fábrica           12 meses  MLA1151530200
# 0  Garantía del vendedor            6 meses  MLA1149134293
# 0    Garantía de fábrica           12 meses  MLA1135443731
# 0    Garantía de fábrica             1 años   MLA913506600
# 0    Garantía de fábrica           12 meses  MLA1138721902

# %% [markdown]
# ### Juntamos todos los dataframes

# %%
display(df.columns)
display(df.shape)
display(df.id.nunique())
# Out:
# Index(['id', 'title', 'seller_id', 'price', 'base_price', 'deal_ids',
#        'initial_quantity', 'sold_quantity', 'listing_type_id',
#        'available_quantity', 'sold_quantity', 'sale_terms', 'condition',
#        'installment', 'display_size', 'shipping_cost', 'descriptions',
#        'attributes', 'warnings', 'status', 'date_created', 'shipping.mode',
#        'shipping.free_shipping'],
#       dtype='object')
# (11574, 23)
# 9739

# %%
df_attributes.drop_duplicates(inplace = True)
display(df_attributes.columns)
display(df_attributes.shape)
display(df_attributes.id.nunique())
# Out:
# Index(['Tipo de batería', 'Marca', 'Cantidad de núcleos',
#        'Resolución de la pantalla', 'Tamaño de la pantalla',
#        'Tipo de pantalla', 'Tarjeta gráfica', 'Es 2 en 1', 'Es gamer',
#        'Es ultrabook', 'Condición del ítem', 'Línea', 'Modelo',
#        'Edición del sistema operativo', 'Nombre del sistema operativo',
#        'Versión del sistema operativo', 'Marca del procesador',
#        'Línea del procesador', 'Memoria RAM', 'Tipo de memoria RAM',
#        'Capacidad del SSD', 'Cantidad total de puertos USB', 'Peso',
#        'Con Bluetooth', 'Con puerto ethernet', 'Con HDMI',
#        'Con salida para auriculares', 'Con lector de tarjeta de memoria',
#        'Con micrófono', 'Con pantalla táctil', 'Con cámara web', 'Con Wi-Fi',
#        'id', 'Profundidad', 'Altura', 'Modos de sonido', 'Puertos USB',
#        'Puertos de video', 'Ancho', 'Con USB'],
#       dtype='object')
# (9739, 40)
# 9739

# %%
df_st.drop_duplicates(inplace = True)
display(df_st.columns)
display(df_st.shape)
display(df_st.id.nunique())
# Out:
# Index(['Tipo de garantía', 'Tiempo de garantía', 'id'], dtype='object')
# (9532, 3)
# 9532

# %% [markdown]
# #### Merge

# %%
display(df.shape)
df = df.merge(df_attributes, on = "id", how = "left")
display(df.shape)
# Out:
# (11574, 23)
# (11574, 25)

# %%
display(df.shape)
df = df.merge(df_st, on = "id", how = "left")
display(df_.shape)
# Out:
# (11574, 62)
# (11574, 25)

# %%
df.head()
# Out:
#               id                                              title  \
# 0  MLA1151530200  Notebook Lenovo Ideapad 3 14iil05 Intel Core I...
# 1  MLA1149134293  Notebook Lenovo Ideapad 14iil05  Platinum Gray...
# 2  MLA1135443731  Notebook Exo Smart L33e Gris 14 , Intel Celero...
# 3   MLA913506600  Notebook Banghó Max L4 I1 Gris Oscura 14 , Int...
# 4  MLA1138721902  Notebook Hp 14-dq2029la Plata Natural 14 , Int...
#
#     seller_id        price   base_price                           deal_ids  \
# 0   174556876  89999.00000  89999.00000                        ['MLA6015']
# 1   335450469 132616.00000 132616.00000                                 []
# 2    25704919  59999.00000  59999.00000  ['MLA8258', 'MLA9166', 'MLA6015']
# 3    31875925  71999.00000  71999.00000                        ['MLA8755']
# 4  1006692747 139999.00000 139999.00000            ['MLA8258', 'MLA11620']
#
#    initial_quantity  sold_quantity listing_type_id  available_quantity  \
# 0               105             50    gold_special                   1
# 1                75             50    gold_special                   1
# 2               482            250    gold_special                   1
# 3              9979            500    gold_special                5000
# 4               339            250    gold_special                   1
#
#    sold_quantity                                         sale_terms condition  \
# 0             50  [{'id': 'WARRANTY_TYPE', 'name': 'Tipo de gara...       new
# 1             50  [{'id': 'WARRANTY_TYPE', 'name': 'Tipo de gara...       new
# 2            250  [{'id': 'INVOICE', 'name': 'Facturación', 'val...       new
# 3            500  [{'id': 'WARRANTY_TYPE', 'name': 'Tipo de gara...       new
# 4            250  [{'id': 'WARRANTY_TYPE', 'name': 'Tipo de gara...       new
#
#   installment display_size shipping_cost descriptions  \
# 0         yes   hasta 14.1          free           []
# 1         yes   hasta 14.1          free           []
# 2         yes   hasta 14.1          free           []
# 3         yes   hasta 14.1          free           []
# 4         yes   hasta 14.1          free           []
#
#                                           attributes warnings  status  \
# 0  [{'id': 'BATTERY_TYPE', 'name': 'Tipo de bater...       []  active
# 1  [{'id': 'ALPHANUMERIC_MODEL', 'name': 'Modelo ...       []  active
# 2  [{'id': 'ASPECT_RATIO', 'name': 'Relación de a...       []  active
# 3  [{'id': 'GPU', 'name': 'GPU', 'value_id': '301...       []  active
# 4  [{'id': 'ASPECT_RATIO', 'name': 'Relación de a...       []  active
#
#                date_created shipping.mode  shipping.free_shipping  \
# 0  2022-08-11T16:12:19.000Z           me2                    True
# 1  2022-08-01T19:07:12.000Z           me2                    True
# 2  2022-05-04T15:42:38.000Z           me2                    True
# 3  2021-03-25T22:07:13.000Z           me2                    True
# 4  2022-05-24T18:58:45.000Z           me2                    True
#
#      Tipo de batería   Marca Cantidad de núcleos Resolución de la pantalla  \
# 0       Ion de litio  Lenovo                   2         1920 px x 1080 px
# 1  Polímero de litio  Lenovo                   4         1920 px x 1080 px
# 2                NaN     EXO                   2          1366 px x 768 px
# 3       Ion de litio  Banghó                   2          1366 px x 768 px
# 4       Ion de litio      HP                   4          1366 px x 768 px
#
#   Tamaño de la pantalla Tipo de pantalla                  Tarjeta gráfica  \
# 0                  14 "              LCD               Intel UHD Graphics
# 1                  14 "              LCD            Intel UHD Graphics G1
# 2                  14 "              LED           Intel UHD Graphics 600
# 3                  14 "              LCD           Intel UHD Graphics 600
# 4                  14 "              NaN  Intel Iris Xe Graphics G7 80EUs
#
#   Es 2 en 1 Es gamer Es ultrabook Condición del ítem       Línea       Modelo  \
# 0        No       No           No              Nuevo   IDEAPAD 3      14IIL05
# 1       NaN      NaN          NaN              Nuevo     IdeaPad            3
# 2       NaN      NaN          NaN              Nuevo       Smart         L33E
# 3        No       No           No              Nuevo         Max        L4 i1
# 4        No       No           No              Nuevo  Intel Core  14-dq2029la
#
#   Edición del sistema operativo Nombre del sistema operativo  \
# 0                             S                      Windows
# 1                          Home                      Windows
# 2                          Home                      Windows
# 3                          Home                      Windows
# 4                          Home                      Windows
#
#   Versión del sistema operativo Marca del procesador Línea del procesador  \
# 0                            11                Intel              Core i3
# 1                            10                Intel              Core i5
# 2                            10                Intel              Celeron
# 3                            10                Intel              Celeron
# 4                            10                Intel              Core i5
#
#   Memoria RAM Tipo de memoria RAM Capacidad del SSD  \
# 0        8 GB                DDR4            128 GB
# 1        8 GB                DDR4            512 GB
# 2        4 GB                DDR4             64 GB
# 3        4 GB                DDR4            120 GB
# 4        8 GB                DDR4            256 GB
#
#   Cantidad total de puertos USB     Peso Con Bluetooth Con puerto ethernet  \
# 0                             3   1.6 kg            Sí                  No
# 1                             3   1.6 kg            Sí                  No
# 2                             2   1350 g            Sí                 NaN
# 3                             3   1.3 kg            Sí                  No
# 4                             3  1.46 kg            Sí                 NaN
#
#   Con HDMI Con salida para auriculares Con lector de tarjeta de memoria  \
# 0       Sí                          Sí                               Sí
# 1       Sí                          Sí                               Sí
# 2       Sí                          Sí                               Sí
# 3       Sí                          Sí                               Sí
# 4       Sí                          Sí                               Sí
#
#   Con micrófono Con pantalla táctil Con cámara web Con Wi-Fi Profundidad  \
# 0            Sí                  No             Sí        Sí         NaN
# 1            Sí                  No             Sí        Sí      241 mm
# 2            Sí                 NaN             Sí        Sí      216 mm
# 3            Sí                  No             Sí        Sí    219.5 mm
# 4            Sí                  No             Sí        Sí     22.5 cm
#
#     Altura     Modos de sonido Puertos USB Puertos de video     Ancho Con USB  \
# 0      NaN                 NaN         NaN              NaN       NaN     NaN
# 1  19.9 mm  Dolby Audio,Stereo     2.0,3.2             HDMI  327.1 mm      Sí
# 2  22.2 mm                 NaN     2.0,3.0        Mini-HDMI    327 mm      Sí
# 3  18.3 mm              Stereo   2.0,3.1,C             HDMI  324.9 mm      Sí
# 4  1.79 cm              Stereo   A3.0,C3.0             HDMI   32.4 cm      Sí
#
#         Tipo de garantía Tiempo de garantía
# 0    Garantía de fábrica           12 meses
# 1  Garantía del vendedor            6 meses
# 2    Garantía de fábrica           12 meses
# 3    Garantía de fábrica             1 años
# 4    Garantía de fábrica           12 meses

# %%
df.to_csv(path / "datos_laptops_transformed.csv", index = False, sep = ";")
