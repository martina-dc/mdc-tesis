# %% [markdown]
# # Data labeling
# En este notebook lo que haremos es por un lado tomar el dataset que contiene las 10000 laptops descargadas y comprender las columnas que obtuvimos.
# Por otro lado lo que haremos es cargar en una columna nueva un path a donde se encuentran ubicadas las imagenes de este laptop.
# Una vez que entendamos cuantas laptops con fotos tenemos y cuantas pudimos etiquetar, separaremos el dataset en 3. Una parte para entrenamiento, otra para validacion y otra para test. Aquellas que quedaron sin etiqueta son las que querremos etiquetar para poder incorporarlas a nuestra database de donde sacaremos las recomendaciones a los clientes.
#
# El etiquetado buscara clasificar las notebooks en 3 tipos:
#
# - Tradicional economica
# - Tradicional premium
# - Gamers

# %%
import pandas as pd
import os
import json
import ast
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
path = "/content/drive/MyDrive/Austral/Maestria/Tesis/Data"

# %%
df = pd.read_csv(path + "datos_laptops.csv",  sep = ";")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (42,72) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ## Preview del dataset

# %%
df.head(3)
# Out:
#               id site_id                                              title  \
# 0  MLA1129251702     MLA  Notebook Hp Amd Ryzen 7 5700u 12gb 256gb Ssd 1...
# 1  MLA1147028688     MLA  Notebook Hp 15-ef2126wm Spruce Blue 15.6 , Amd...
# 2  MLA1110784573     MLA  Notebook Noblex 14.1  Pantalla Hd Intel Celero...
#
#    subtitle  seller_id category_id  official_store_id        price  \
# 0       NaN  174556876     MLA1652                NaN 164899.00000
# 1       NaN  158169010     MLA1652                NaN 129499.00000
# 2       NaN  185702920     MLA1652                NaN  66999.00000
#
#     base_price  original_price currency_id  initial_quantity  \
# 0 164899.00000    179999.00000         ARS                43
# 1 129499.00000             NaN         ARS                42
# 2  66999.00000             NaN         ARS                81
#
#    available_quantity  sold_quantity  \
# 0                   1              5
# 1                   0             25
# 2                   1             50
#
#                                           sale_terms buying_mode  \
# 0  [{'id': 'WARRANTY_TYPE', 'name': 'Tipo de gara...  buy_it_now
# 1  [{'id': 'INVOICE', 'name': 'Facturación', 'val...  buy_it_now
# 2  [{'id': 'WARRANTY_TIME', 'name': 'Tiempo de ga...  buy_it_now
#
#   listing_type_id                start_time                 stop_time  \
# 0    gold_special  2022-03-25T16:19:38.000Z  2042-03-20T04:00:00.000Z
# 1    gold_special  2022-07-15T15:09:59.000Z  2042-07-10T04:00:00.000Z
# 2    gold_special  2021-11-02T17:35:08.000Z  2041-10-28T04:00:00.000Z
#
#   condition                                          permalink  \
# 0       new  https://articulo.mercadolibre.com.ar/MLA-11292...
# 1       new  https://articulo.mercadolibre.com.ar/MLA-11470...
# 2       new  https://articulo.mercadolibre.com.ar/MLA-11107...
#
#                    thumbnail_id  \
# 0  975457-MLA49471206711_032022
# 1  945528-MLA49251126700_032022
# 2  997940-MLA47767920611_102021
#
#                                            thumbnail  \
# 0  http://http2.mlstatic.com/D_975457-MLA49471206...
# 1  http://http2.mlstatic.com/D_945528-MLA49251126...
# 2  http://http2.mlstatic.com/D_997940-MLA47767920...
#
#                                     secure_thumbnail  \
# 0  https://http2.mlstatic.com/D_975457-MLA4947120...
# 1  https://http2.mlstatic.com/D_945528-MLA4925112...
# 2  https://http2.mlstatic.com/D_997940-MLA4776792...
#
#                                             pictures video_id descriptions  \
# 0  [{'id': '975457-MLA49471206711_032022', 'url':...      NaN           []
# 1  [{'id': '945528-MLA49251126700_032022', 'url':...      NaN           []
# 2  [{'id': '997940-MLA47767920611_102021', 'url':...      NaN           []
#
#    accepts_mercadopago non_mercado_pago_payment_methods  \
# 0                 True                               []
# 1                 True                               []
# 2                 True                               []
#
#   international_delivery_mode  seller_contact coverage_areas  \
# 0                        none             NaN             []
# 1                        none             NaN             []
# 2                        none             NaN             []
#
#                                           attributes warnings  listing_source  \
# 0  [{'id': 'BATTERY_LIFE', 'name': 'Duración de l...       []             NaN
# 1  [{'id': 'ASPECT_RATIO', 'name': 'Relación de a...       []             NaN
# 2  [{'id': 'ALPHANUMERIC_MODEL', 'name': 'Modelo ...       []             NaN
#
#                                           variations  status  \
# 0  [{'id': 174343023835, 'price': 164899.0, 'attr...  active
# 1                                                 []  paused
# 2                                                 []  active
#
#          sub_status                                               tags  \
# 0                []  ['deal_of_the_day', 'extended_warranty_eligibl...
# 1  ['out_of_stock']  ['extended_warranty_eligible', 'good_quality_p...
# 2                []  ['extended_warranty_eligible', 'good_quality_p...
#
#                          warranty catalog_product_id      domain_id  \
# 0   Garantía de fábrica: 12 meses                NaN  MLA-NOTEBOOKS
# 1  Garantía del vendedor: 6 meses        MLA18717712  MLA-NOTEBOOKS
# 2   Garantía de fábrica: 12 meses        MLA18547226  MLA-NOTEBOOKS
#
#   parent_item_id  differential_pricing  \
# 0            NaN                   NaN
# 1            NaN                   NaN
# 2            NaN                   NaN
#
#                                          deal_ids  automatic_relist  \
# 0  ['MLA8258', 'MLA12440', 'MLA6015', 'MLA12436']             False
# 1                                              []             False
# 2                                     ['MLA9166']             False
#
#                date_created              last_updated  health  \
# 0  2022-03-25T16:19:38.000Z  2022-08-11T20:54:11.550Z 0.90000
# 1  2022-07-15T15:10:00.000Z  2022-08-11T21:29:46.849Z     NaN
# 2  2021-11-02T17:35:09.000Z  2022-08-11T17:42:25.861Z     NaN
#
#    catalog_listing                   channels shipping.mode shipping.methods  \
# 0            False  ['marketplace', 'mshops']           me2               []
# 1             True            ['marketplace']           me2               []
# 2             True  ['marketplace', 'mshops']           me2               []
#
#                                        shipping.tags  shipping.dimensions  \
# 0     ['self_service_in', 'mandatory_free_shipping']                  NaN
# 1  ['self_service_in', 'fbm_in_process', 'mandato...                  NaN
# 2     ['self_service_in', 'mandatory_free_shipping']                  NaN
#
#    shipping.local_pick_up  shipping.free_shipping shipping.logistic_type  \
# 0                    True                    True          cross_docking
# 1                    True                    True            xd_drop_off
# 2                   False                    True            fulfillment
#
#    shipping.store_pick_up seller_address.city.id seller_address.city.name  \
# 0                   False       TUxBQlZJTDQyMjBa             Villa Crespo
# 1                   False       TUxBQ0NBUGNiZGQx                  Córdoba
# 2                   False       TUxBQk1PTjE2OTBa             Monte Castro
#
#   seller_address.state.id seller_address.state.name seller_address.country.id  \
# 0                    AR-C           Capital Federal                        AR
# 1                    AR-X                   Córdoba                        AR
# 2                    AR-C           Capital Federal                        AR
#
#   seller_address.country.name seller_address.search_location.neighborhood.id  \
# 0                   Argentina                               TUxBQlZJTDQyMjBa
# 1                   Argentina                                            NaN
# 2                   Argentina                               TUxBQk1PTjE2OTBa
#
#   seller_address.search_location.neighborhood.name  \
# 0                                     Villa Crespo
# 1                                              NaN
# 2                                     Monte Castro
#
#   seller_address.search_location.city.id  \
# 0                     TUxBQ0NBUGZlZG1sYQ
# 1                       TUxBQ0NBUGNiZGQx
# 2                     TUxBQ0NBUGZlZG1sYQ
#
#   seller_address.search_location.city.name  \
# 0                          Capital Federal
# 1                                  Córdoba
# 2                          Capital Federal
#
#   seller_address.search_location.state.id  \
# 0                        TUxBUENBUGw3M2E1
# 1                        TUxBUENPUmFkZGIw
# 2                        TUxBUENBUGw3M2E1
#
#   seller_address.search_location.state.name  seller_address.id  \
# 0                           Capital Federal          155782338
# 1                                   Córdoba          269536971
# 2                           Capital Federal         1117498971
#
#   shipping.free_methods
# 0                   NaN
# 1                   NaN
# 2                   NaN

# %%
df = df[["id", "title", "price", "base_price", "sale_terms", "permalink", "pictures", "attributes"]]
df.head()
# Out:
#               id                                              title  \
# 0  MLA1129251702  Notebook Hp Amd Ryzen 7 5700u 12gb 256gb Ssd 1...
# 1  MLA1147028688  Notebook Hp 15-ef2126wm Spruce Blue 15.6 , Amd...
# 2  MLA1110784573  Notebook Noblex 14.1  Pantalla Hd Intel Celero...
# 3  MLA1149134293  Notebook Lenovo Ideapad 14iil05  Platinum Gray...
# 4  MLA1140410405  Notebook Exo Smart Xq3h-s3182 Plateada 15.6 , ...
#
#          price   base_price  \
# 0 164899.00000 164899.00000
# 1 129499.00000 129499.00000
# 2  66999.00000  66999.00000
# 3 138100.00000 138100.00000
# 4 129999.00000 129999.00000
#
#                                           sale_terms  \
# 0  [{'id': 'WARRANTY_TYPE', 'name': 'Tipo de gara...
# 1  [{'id': 'INVOICE', 'name': 'Facturación', 'val...
# 2  [{'id': 'WARRANTY_TIME', 'name': 'Tiempo de ga...
# 3  [{'id': 'WARRANTY_TYPE', 'name': 'Tipo de gara...
# 4  [{'id': 'WARRANTY_TIME', 'name': 'Tiempo de ga...
#
#                                            permalink  \
# 0  https://articulo.mercadolibre.com.ar/MLA-11292...
# 1  https://articulo.mercadolibre.com.ar/MLA-11470...
# 2  https://articulo.mercadolibre.com.ar/MLA-11107...
# 3  https://articulo.mercadolibre.com.ar/MLA-11491...
# 4  https://articulo.mercadolibre.com.ar/MLA-11404...
#
#                                             pictures  \
# 0  [{'id': '975457-MLA49471206711_032022', 'url':...
# 1  [{'id': '945528-MLA49251126700_032022', 'url':...
# 2  [{'id': '997940-MLA47767920611_102021', 'url':...
# 3  [{'id': '879170-MLA45629747467_042021', 'url':...
# 4  [{'id': '988078-MLA49523884623_032022', 'url':...
#
#                                           attributes
# 0  [{'id': 'BATTERY_LIFE', 'name': 'Duración de l...
# 1  [{'id': 'ASPECT_RATIO', 'name': 'Relación de a...
# 2  [{'id': 'ALPHANUMERIC_MODEL', 'name': 'Modelo ...
# 3  [{'id': 'ALPHANUMERIC_MODEL', 'name': 'Modelo ...
# 4  [{'id': 'ADDITIONAL_INFO_REQUIRED', 'name': 'I...

# %%
df.shape
# Out:
# (33835, 8)

# %%
df_attributes = df[["id","attributes"]].copy()
dummy = df_attributes["attributes"].apply(lambda x: ast.literal_eval(x))

# %%
def get_attributes_from_row(row):
  fila = dict()
  for e in row:
    for element in e:
      #print(element)
      fila[str(element['name'])] =  element['value_name']
    
  return pd.DataFrame.from_dict(fila, orient='index').transpose()

# %%
lista_filas = []
lista_id = []
for (index_dummy, row), (index_df, rowa) in zip(pd.DataFrame(dummy).iterrows(), df_attributes.iterrows()):
  lista_filas.append(get_attributes_from_row(row))
  lista_id.append(rowa['id'])

# %%
for df1, df2 in zip(lista_filas, lista_id):
  df1["id"] = df2

df_attributes = pd.concat(lista_filas)
df_attributes.head()
# Out:
#   Duración de la batería    Tipo de batería   Marca Cantidad de núcleos  \
# 0                   10 h       Ion de litio      HP                None
# 0                  9.3 h       Ion de litio      HP                   6
# 0                    NaN       Ion de litio  Noblex                   2
# 0                  7.7 h  Polímero de litio  Lenovo                   4
# 0                    NaN  Polímero de litio     EXO                   2
#
#   Frecuencia de actualización de la pantalla Resolución de la pantalla  \
# 0                                       None          1366 px x 768 px
# 0                                        NaN         1920 px x 1080 px
# 0                                      60 Hz          1366 px x 768 px
# 0                                        NaN         1920 px x 1080 px
# 0                                      60 Hz         1920 px x 1080 px
#
#   Tamaño de la pantalla                 Tarjeta gráfica  \
# 0                15.6 "                            None
# 0                15.6 "            AMD Radeon RX Vega 7
# 0                14.1 "                            None
# 0                  14 "           Intel UHD Graphics G1
# 0                15.6 "  Intel UHD Graphics Xe G4 48EUs
#
#   Capacidad del disco rígido Es 2 en 1 Es gamer Es ultrabook  \
# 0                       None        No       Sí           No
# 0                        NaN        No       No           No
# 0                       None        No       No           No
# 0                       1 TB       NaN      NaN          NaN
# 0                       None        No       No           No
#
#   Condición del ítem Idioma del teclado     Línea       Modelo  \
# 0              Nuevo             Inglés       N/A  15-EF2081MS
# 0              Nuevo                NaN  ef2126wm  15-ef2126wm
# 0              Nuevo                NaN  Notebook    N14WCE128
# 0              Nuevo                NaN   IdeaPad            3
# 0              Nuevo                NaN     Smart   XQ3H-S3182
#
#   Capacidad Optane Unidades ópticas Edición del sistema operativo  \
# 0             None             None                          None
# 0              NaN              NaN                          Home
# 0             None             None                          Home
# 0              NaN              NaN                          Home
# 0             None             None                          Home
#
#   Nombre del sistema operativo Versión del sistema operativo  \
# 0                      Windows                            11
# 0                      Windows                            10
# 0                      Windows                            10
# 0                      Windows                            10
# 0                      Windows                            11
#
#   Marca del procesador Línea del procesador Memoria RAM Tipo de memoria RAM  \
# 0                  AMD              Ryzen 7       12 GB                DDR4
# 0                  AMD              Ryzen 5        8 GB                DDR4
# 0                Intel              Celeron        4 GB                None
# 0                Intel              Core i5        8 GB                DDR4
# 0                Intel              Core i3        8 GB                DDR4
#
#   Capacidad del SSD Memoria de video     Peso Con Bluetooth  \
# 0            256 GB             None  1.74 kg            Sí
# 0            256 GB              NaN  1.69 kg            Sí
# 0            128 GB             None   1.5 kg            Sí
# 0            512 GB              NaN   1.6 kg            Sí
# 0            256 GB             None   1850 g            Sí
#
#   Con lector de huella digital Con HDMI Con micrófono Con pantalla táctil  \
# 0                           Sí       Sí            Sí                  Sí
# 0                           No       Sí            Sí                  No
# 0                           No       Sí            Sí                  No
# 0                           No       Sí            Sí                  No
# 0                          NaN       Sí            Sí                  No
#
#   Con USB Con Wi-Fi             id Relación de aspecto          Color  \
# 0      Sí        Sí  MLA1129251702                 NaN            NaN
# 0      Sí        Sí  MLA1147028688                16:9    Spruce blue
# 0      Sí        Sí  MLA1110784573                16:9       Plateado
# 0      Sí        Sí  MLA1149134293                16:9  Platinum gray
# 0      Sí        Sí  MLA1140410405                16:9       Plateado
#
#   Gama de colores Profundidad Modelo detallado  \
# 0             NaN         NaN              NaN
# 0        45% NTSC     24.2 cm          4J771UA
# 0             NaN        3 cm      94N14WCE128
# 0             NaN      241 mm       81WD00U9US
# 0             NaN         NaN              NaN
#
#   Tipo de resolución de la pantalla  Código universal de producto   Altura  \
# 0                                NaN                          NaN      NaN
# 0                            Full HD                 196068804015  1.79 cm
# 0                                 HD                7798192367744    22 cm
# 0                            Full HD                0196119591499  19.9 mm
# 0                            Full HD                7797678017821      NaN
#
#   Incluye lápiz Color principal Velocidad máxima del procesador  \
# 0           NaN             NaN                             NaN
# 0            No            Azul                           4 GHz
# 0            No            Gris                             NaN
# 0           NaN        Plateado                         3.6 GHz
# 0           NaN        Plateado                         4.1 GHz
#
#   Velocidad mínima del procesador            MPN Modelo del procesador  \
# 0                             NaN            NaN                   NaN
# 0                         2.1 GHz        4J771UA                 5500U
# 0                             NaN  7798192367744                 N3350
# 0                             NaN     81WD00U9US                1035G1
# 0                           3 GHz         XQ3H-8                1115G4
#
#   Velocidad de la memoria RAM Cantidad de ranuras para la memoria RAM  \
# 0                         NaN                                     NaN
# 0                    3200 MHz                                       2
# 0                         NaN                                     NaN
# 0                    2666 MHz                                       2
# 0                         NaN                                     NaN
#
#               Software incluidos     Modos de sonido Cantidad de parlantes  \
# 0                            NaN                 NaN                   NaN
# 0  McAfee LiveSafe,Microsoft 365              Stereo                     2
# 0                            NaN              Stereo                     2
# 0                            NaN  Dolby Audio,Stereo                     2
# 0                            NaN              Stereo                     2
#
#   Interfaz del SSD          Puertos USB Cantidad total de puertos USB  \
# 0              NaN                  NaN                           NaN
# 0             PCIe  USB-C 3.0,USB-A 3.0                             3
# 0              NaN                  NaN                             2
# 0             PCIe              2.0,3.2                             3
# 0              M.2                 A3.0                             2
#
#   Puertos de video Resolución de video de la cámara web  \
# 0              NaN                                  NaN
# 0             HDMI                     1280 px x 720 px
# 0        Mini-HDMI                                  NaN
# 0             HDMI                                  NaN
# 0             HDMI                     1280 px x 720 px
#
#   Tipo de resolución de video de la cámara web     Ancho  \
# 0                                          NaN       NaN
# 0                                           HD  35.85 cm
# 0                                          NaN     34 cm
# 0                                          NaN  327.1 mm
# 0                                           HD       NaN
#
#   Con pantalla antirreflejo Con salida para auriculares  \
# 0                       NaN                         NaN
# 0                        Sí                          Sí
# 0                       NaN                          Sí
# 0                        Sí                          Sí
# 0                       NaN                          Sí
#
#   Con lector de tarjeta de memoria Con pad numérico Con pantalla retina  \
# 0                              NaN              NaN                 NaN
# 0                               Sí               Sí                  No
# 0                               Sí               No                  No
# 0                               Sí              NaN                 NaN
# 0                               Sí               Sí                 NaN
#
#   Con cámara web Modelo alfanumérico Tipo de pantalla  \
# 0            NaN                 NaN              NaN
# 0             Sí                 NaN              NaN
# 0             Sí         94N14WCE128              LED
# 0             Sí             14IIL05              LCD
# 0             Sí                 NaN              LED
#
#   Capacidad máxima soportada de la memoria RAM Altura del paquete  \
# 0                                          NaN                NaN
# 0                                          NaN                NaN
# 0                                         4 GB             8.2 cm
# 0                                        12 GB                NaN
# 0                                          NaN             5.8 cm
#
#   Largo del paquete Peso del paquete Ancho del paquete            SKU  \
# 0               NaN              NaN               NaN            NaN
# 0               NaN              NaN               NaN            NaN
# 0           24.6 cm           1760 g           35.4 cm  7798192367744
# 0               NaN              NaN               NaN     81WA00Q7US
# 0           48.6 cm           2640 g           28.2 cm           7248
#
#   Resolución de la imagen fija de la cámara web Con teclado retroiluminado  \
# 0                                           NaN                        NaN
# 0                                           NaN                        NaN
# 0                                         2 Mpx                         No
# 0                                       0.3 Mpx                         No
# 0                                           NaN                        NaN
#
#   Con puerto ethernet Información adicional requerida  \
# 0                 NaN                             NaN
# 0                 NaN                             NaN
# 0                  No                             NaN
# 0                  No                             NaN
# 0                  Sí           Tiene número de serie
#
#   Características del producto Embalaje del envío Canal exclusivo  \
# 0                          NaN                NaN             NaN
# 0                          NaN                NaN             NaN
# 0                          NaN                NaN             NaN
# 0                          NaN                NaN             NaN
# 0       Frágil,Sin vencimiento               Caja             NaN
#
#   Tipo de panel Tipo de resolución Interfaz del disco rígido  GPU  \
# 0           NaN                NaN                       NaN  NaN
# 0           NaN                NaN                       NaN  NaN
# 0           NaN                NaN                       NaN  NaN
# 0           NaN                NaN                       NaN  NaN
# 0           NaN                NaN                       NaN  NaN
#
#   Velocidad del procesador Resolución de la cámara web Accesorios incluidos  \
# 0                      NaN                         NaN                  NaN
# 0                      NaN                         NaN                  NaN
# 0                      NaN                         NaN                  NaN
# 0                      NaN                         NaN                  NaN
# 0                      NaN                         NaN                  NaN
#
#   Tipos de memoria de video Características de las baterías  \
# 0                       NaN                             NaN
# 0                       NaN                             NaN
# 0                       NaN                             NaN
# 0                       NaN                             NaN
# 0                       NaN                             NaN
#
#   Tipo de almacenamiento de datos Capacidad de almacenamiento Es kit  \
# 0                             NaN                         NaN    NaN
# 0                             NaN                         NaN    NaN
# 0                             NaN                         NaN    NaN
# 0                             NaN                         NaN    NaN
# 0                             NaN                         NaN    NaN
#
#   Fuente del producto Disponibilidad de stock Procesador Tags descriptivos  \
# 0                 NaN                     NaN        NaN               NaN
# 0                 NaN                     NaN        NaN               NaN
# 0                 NaN                     NaN        NaN               NaN
# 0                 NaN                     NaN        NaN               NaN
# 0                 NaN                     NaN        NaN               NaN
#
#   Largo Serie Máxima capacidad de RAM Características químicas del producto
# 0   NaN   NaN                     NaN                                   NaN
# 0   NaN   NaN                     NaN                                   NaN
# 0   NaN   NaN                     NaN                                   NaN
# 0   NaN   NaN                     NaN                                   NaN
# 0   NaN   NaN                     NaN                                   NaN

# %%
df = df.drop_duplicates()
df_attributes = df_attributes.drop_duplicates()

# %%
df.shape[0] == df.id.nunique()
# Out:
# False

# %%
df_attributes.shape[0] == df_attributes.id.nunique()
# Out:
# True

# %%
df = df.merge(df_attributes,
               how = "left",
               on = "id")
df.head()
# Out:
#               id                                              title  \
# 0  MLA1129251702  Notebook Hp Amd Ryzen 7 5700u 12gb 256gb Ssd 1...
# 1  MLA1147028688  Notebook Hp 15-ef2126wm Spruce Blue 15.6 , Amd...
# 2  MLA1110784573  Notebook Noblex 14.1  Pantalla Hd Intel Celero...
# 3  MLA1149134293  Notebook Lenovo Ideapad 14iil05  Platinum Gray...
# 4  MLA1140410405  Notebook Exo Smart Xq3h-s3182 Plateada 15.6 , ...
#
#          price   base_price  \
# 0 164899.00000 164899.00000
# 1 129499.00000 129499.00000
# 2  66999.00000  66999.00000
# 3 138100.00000 138100.00000
# 4 129999.00000 129999.00000
#
#                                           sale_terms  \
# 0  [{'id': 'WARRANTY_TYPE', 'name': 'Tipo de gara...
# 1  [{'id': 'INVOICE', 'name': 'Facturación', 'val...
# 2  [{'id': 'WARRANTY_TIME', 'name': 'Tiempo de ga...
# 3  [{'id': 'WARRANTY_TYPE', 'name': 'Tipo de gara...
# 4  [{'id': 'WARRANTY_TIME', 'name': 'Tiempo de ga...
#
#                                            permalink  \
# 0  https://articulo.mercadolibre.com.ar/MLA-11292...
# 1  https://articulo.mercadolibre.com.ar/MLA-11470...
# 2  https://articulo.mercadolibre.com.ar/MLA-11107...
# 3  https://articulo.mercadolibre.com.ar/MLA-11491...
# 4  https://articulo.mercadolibre.com.ar/MLA-11404...
#
#                                             pictures  \
# 0  [{'id': '975457-MLA49471206711_032022', 'url':...
# 1  [{'id': '945528-MLA49251126700_032022', 'url':...
# 2  [{'id': '997940-MLA47767920611_102021', 'url':...
# 3  [{'id': '879170-MLA45629747467_042021', 'url':...
# 4  [{'id': '988078-MLA49523884623_032022', 'url':...
#
#                                           attributes Duración de la batería  \
# 0  [{'id': 'BATTERY_LIFE', 'name': 'Duración de l...                   10 h
# 1  [{'id': 'ASPECT_RATIO', 'name': 'Relación de a...                  9.3 h
# 2  [{'id': 'ALPHANUMERIC_MODEL', 'name': 'Modelo ...                    NaN
# 3  [{'id': 'ALPHANUMERIC_MODEL', 'name': 'Modelo ...                  7.7 h
# 4  [{'id': 'ADDITIONAL_INFO_REQUIRED', 'name': 'I...                    NaN
#
#      Tipo de batería   Marca Cantidad de núcleos  \
# 0       Ion de litio      HP                None
# 1       Ion de litio      HP                   6
# 2       Ion de litio  Noblex                   2
# 3  Polímero de litio  Lenovo                   4
# 4  Polímero de litio     EXO                   2
#
#   Frecuencia de actualización de la pantalla Resolución de la pantalla  \
# 0                                       None          1366 px x 768 px
# 1                                        NaN         1920 px x 1080 px
# 2                                      60 Hz          1366 px x 768 px
# 3                                        NaN         1920 px x 1080 px
# 4                                      60 Hz         1920 px x 1080 px
#
#   Tamaño de la pantalla                 Tarjeta gráfica  \
# 0                15.6 "                            None
# 1                15.6 "            AMD Radeon RX Vega 7
# 2                14.1 "                            None
# 3                  14 "           Intel UHD Graphics G1
# 4                15.6 "  Intel UHD Graphics Xe G4 48EUs
#
#   Capacidad del disco rígido Es 2 en 1 Es gamer Es ultrabook  \
# 0                       None        No       Sí           No
# 1                        NaN        No       No           No
# 2                       None        No       No           No
# 3                       1 TB       NaN      NaN          NaN
# 4                       None        No       No           No
#
#   Condición del ítem Idioma del teclado     Línea       Modelo  \
# 0              Nuevo             Inglés       N/A  15-EF2081MS
# 1              Nuevo                NaN  ef2126wm  15-ef2126wm
# 2              Nuevo                NaN  Notebook    N14WCE128
# 3              Nuevo                NaN   IdeaPad            3
# 4              Nuevo                NaN     Smart   XQ3H-S3182
#
#   Capacidad Optane Unidades ópticas Edición del sistema operativo  \
# 0             None             None                          None
# 1              NaN              NaN                          Home
# 2             None             None                          Home
# 3              NaN              NaN                          Home
# 4             None             None                          Home
#
#   Nombre del sistema operativo Versión del sistema operativo  \
# 0                      Windows                            11
# 1                      Windows                            10
# 2                      Windows                            10
# 3                      Windows                            10
# 4                      Windows                            11
#
#   Marca del procesador Línea del procesador Memoria RAM Tipo de memoria RAM  \
# 0                  AMD              Ryzen 7       12 GB                DDR4
# 1                  AMD              Ryzen 5        8 GB                DDR4
# 2                Intel              Celeron        4 GB                None
# 3                Intel              Core i5        8 GB                DDR4
# 4                Intel              Core i3        8 GB                DDR4
#
#   Capacidad del SSD Memoria de video     Peso Con Bluetooth  \
# 0            256 GB             None  1.74 kg            Sí
# 1            256 GB              NaN  1.69 kg            Sí
# 2            128 GB             None   1.5 kg            Sí
# 3            512 GB              NaN   1.6 kg            Sí
# 4            256 GB             None   1850 g            Sí
#
#   Con lector de huella digital Con HDMI Con micrófono Con pantalla táctil  \
# 0                           Sí       Sí            Sí                  Sí
# 1                           No       Sí            Sí                  No
# 2                           No       Sí            Sí                  No
# 3                           No       Sí            Sí                  No
# 4                          NaN       Sí            Sí                  No
#
#   Con USB Con Wi-Fi Relación de aspecto          Color Gama de colores  \
# 0      Sí        Sí                 NaN            NaN             NaN
# 1      Sí        Sí                16:9    Spruce blue        45% NTSC
# 2      Sí        Sí                16:9       Plateado             NaN
# 3      Sí        Sí                16:9  Platinum gray             NaN
# 4      Sí        Sí                16:9       Plateado             NaN
#
#   Profundidad Modelo detallado Tipo de resolución de la pantalla   \
# 0         NaN              NaN                                NaN
# 1     24.2 cm          4J771UA                            Full HD
# 2        3 cm      94N14WCE128                                 HD
# 3      241 mm       81WD00U9US                            Full HD
# 4         NaN              NaN                            Full HD
#
#   Código universal de producto   Altura Incluye lápiz Color principal  \
# 0                          NaN      NaN           NaN             NaN
# 1                 196068804015  1.79 cm            No            Azul
# 2                7798192367744    22 cm            No            Gris
# 3                0196119591499  19.9 mm           NaN        Plateado
# 4                7797678017821      NaN           NaN        Plateado
#
#   Velocidad máxima del procesador Velocidad mínima del procesador  \
# 0                             NaN                             NaN
# 1                           4 GHz                         2.1 GHz
# 2                             NaN                             NaN
# 3                         3.6 GHz                             NaN
# 4                         4.1 GHz                           3 GHz
#
#              MPN Modelo del procesador Velocidad de la memoria RAM  \
# 0            NaN                   NaN                         NaN
# 1        4J771UA                 5500U                    3200 MHz
# 2  7798192367744                 N3350                         NaN
# 3     81WD00U9US                1035G1                    2666 MHz
# 4         XQ3H-8                1115G4                         NaN
#
#   Cantidad de ranuras para la memoria RAM             Software incluidos  \
# 0                                     NaN                            NaN
# 1                                       2  McAfee LiveSafe,Microsoft 365
# 2                                     NaN                            NaN
# 3                                       2                            NaN
# 4                                     NaN                            NaN
#
#       Modos de sonido Cantidad de parlantes Interfaz del SSD  \
# 0                 NaN                   NaN              NaN
# 1              Stereo                     2             PCIe
# 2              Stereo                     2              NaN
# 3  Dolby Audio,Stereo                     2             PCIe
# 4              Stereo                     2              M.2
#
#            Puertos USB Cantidad total de puertos USB Puertos de video  \
# 0                  NaN                           NaN              NaN
# 1  USB-C 3.0,USB-A 3.0                             3             HDMI
# 2                  NaN                             2        Mini-HDMI
# 3              2.0,3.2                             3             HDMI
# 4                 A3.0                             2             HDMI
#
#   Resolución de video de la cámara web  \
# 0                                  NaN
# 1                     1280 px x 720 px
# 2                                  NaN
# 3                                  NaN
# 4                     1280 px x 720 px
#
#   Tipo de resolución de video de la cámara web     Ancho  \
# 0                                          NaN       NaN
# 1                                           HD  35.85 cm
# 2                                          NaN     34 cm
# 3                                          NaN  327.1 mm
# 4                                           HD       NaN
#
#   Con pantalla antirreflejo Con salida para auriculares  \
# 0                       NaN                         NaN
# 1                        Sí                          Sí
# 2                       NaN                          Sí
# 3                        Sí                          Sí
# 4                       NaN                          Sí
#
#   Con lector de tarjeta de memoria Con pad numérico Con pantalla retina  \
# 0                              NaN              NaN                 NaN
# 1                               Sí               Sí                  No
# 2                               Sí               No                  No
# 3                               Sí              NaN                 NaN
# 4                               Sí               Sí                 NaN
#
#   Con cámara web Modelo alfanumérico Tipo de pantalla  \
# 0            NaN                 NaN              NaN
# 1             Sí                 NaN              NaN
# 2             Sí         94N14WCE128              LED
# 3             Sí             14IIL05              LCD
# 4             Sí                 NaN              LED
#
#   Capacidad máxima soportada de la memoria RAM Altura del paquete  \
# 0                                          NaN                NaN
# 1                                          NaN                NaN
# 2                                         4 GB             8.2 cm
# 3                                        12 GB                NaN
# 4                                          NaN             5.8 cm
#
#   Largo del paquete Peso del paquete Ancho del paquete            SKU  \
# 0               NaN              NaN               NaN            NaN
# 1               NaN              NaN               NaN            NaN
# 2           24.6 cm           1760 g           35.4 cm  7798192367744
# 3               NaN              NaN               NaN     81WA00Q7US
# 4           48.6 cm           2640 g           28.2 cm           7248
#
#   Resolución de la imagen fija de la cámara web Con teclado retroiluminado  \
# 0                                           NaN                        NaN
# 1                                           NaN                        NaN
# 2                                         2 Mpx                         No
# 3                                       0.3 Mpx                         No
# 4                                           NaN                        NaN
#
#   Con puerto ethernet Información adicional requerida  \
# 0                 NaN                             NaN
# 1                 NaN                             NaN
# 2                  No                             NaN
# 3                  No                             NaN
# 4                  Sí           Tiene número de serie
#
#   Características del producto Embalaje del envío Canal exclusivo  \
# 0                          NaN                NaN             NaN
# 1                          NaN                NaN             NaN
# 2                          NaN                NaN             NaN
# 3                          NaN                NaN             NaN
# 4       Frágil,Sin vencimiento               Caja             NaN
#
#   Tipo de panel Tipo de resolución Interfaz del disco rígido  GPU  \
# 0           NaN                NaN                       NaN  NaN
# 1           NaN                NaN                       NaN  NaN
# 2           NaN                NaN                       NaN  NaN
# 3           NaN                NaN                       NaN  NaN
# 4           NaN                NaN                       NaN  NaN
#
#   Velocidad del procesador Resolución de la cámara web Accesorios incluidos  \
# 0                      NaN                         NaN                  NaN
# 1                      NaN                         NaN                  NaN
# 2                      NaN                         NaN                  NaN
# 3                      NaN                         NaN                  NaN
# 4                      NaN                         NaN                  NaN
#
#   Tipos de memoria de video Características de las baterías  \
# 0                       NaN                             NaN
# 1                       NaN                             NaN
# 2                       NaN                             NaN
# 3                       NaN                             NaN
# 4                       NaN                             NaN
#
#   Tipo de almacenamiento de datos Capacidad de almacenamiento Es kit  \
# 0                             NaN                         NaN    NaN
# 1                             NaN                         NaN    NaN
# 2                             NaN                         NaN    NaN
# 3                             NaN                         NaN    NaN
# 4                             NaN                         NaN    NaN
#
#   Fuente del producto Disponibilidad de stock Procesador Tags descriptivos  \
# 0                 NaN                     NaN        NaN               NaN
# 1                 NaN                     NaN        NaN               NaN
# 2                 NaN                     NaN        NaN               NaN
# 3                 NaN                     NaN        NaN               NaN
# 4                 NaN                     NaN        NaN               NaN
#
#   Largo Serie Máxima capacidad de RAM Características químicas del producto
# 0   NaN   NaN                     NaN                                   NaN
# 1   NaN   NaN                     NaN                                   NaN
# 2   NaN   NaN                     NaN                                   NaN
# 3   NaN   NaN                     NaN                                   NaN
# 4   NaN   NaN                     NaN                                   NaN

# %%
if 'attributes' in df.columns.values:
  del df['attributes']

if 'pictures' in df.columns.values:
  del df['pictures'], 

if 'sale_terms' in df.columns.values:
  del df['sale_terms']

# %%
df.head()
# Out:
#               id                                              title  \
# 0  MLA1129251702  Notebook Hp Amd Ryzen 7 5700u 12gb 256gb Ssd 1...
# 1  MLA1147028688  Notebook Hp 15-ef2126wm Spruce Blue 15.6 , Amd...
# 2  MLA1110784573  Notebook Noblex 14.1  Pantalla Hd Intel Celero...
# 3  MLA1149134293  Notebook Lenovo Ideapad 14iil05  Platinum Gray...
# 4  MLA1140410405  Notebook Exo Smart Xq3h-s3182 Plateada 15.6 , ...
#
#          price   base_price  \
# 0 164899.00000 164899.00000
# 1 129499.00000 129499.00000
# 2  66999.00000  66999.00000
# 3 138100.00000 138100.00000
# 4 129999.00000 129999.00000
#
#                                            permalink Duración de la batería  \
# 0  https://articulo.mercadolibre.com.ar/MLA-11292...                   10 h
# 1  https://articulo.mercadolibre.com.ar/MLA-11470...                  9.3 h
# 2  https://articulo.mercadolibre.com.ar/MLA-11107...                    NaN
# 3  https://articulo.mercadolibre.com.ar/MLA-11491...                  7.7 h
# 4  https://articulo.mercadolibre.com.ar/MLA-11404...                    NaN
#
#      Tipo de batería   Marca Cantidad de núcleos  \
# 0       Ion de litio      HP                None
# 1       Ion de litio      HP                   6
# 2       Ion de litio  Noblex                   2
# 3  Polímero de litio  Lenovo                   4
# 4  Polímero de litio     EXO                   2
#
#   Frecuencia de actualización de la pantalla Resolución de la pantalla  \
# 0                                       None          1366 px x 768 px
# 1                                        NaN         1920 px x 1080 px
# 2                                      60 Hz          1366 px x 768 px
# 3                                        NaN         1920 px x 1080 px
# 4                                      60 Hz         1920 px x 1080 px
#
#   Tamaño de la pantalla                 Tarjeta gráfica  \
# 0                15.6 "                            None
# 1                15.6 "            AMD Radeon RX Vega 7
# 2                14.1 "                            None
# 3                  14 "           Intel UHD Graphics G1
# 4                15.6 "  Intel UHD Graphics Xe G4 48EUs
#
#   Capacidad del disco rígido Es 2 en 1 Es gamer Es ultrabook  \
# 0                       None        No       Sí           No
# 1                        NaN        No       No           No
# 2                       None        No       No           No
# 3                       1 TB       NaN      NaN          NaN
# 4                       None        No       No           No
#
#   Condición del ítem Idioma del teclado     Línea       Modelo  \
# 0              Nuevo             Inglés       N/A  15-EF2081MS
# 1              Nuevo                NaN  ef2126wm  15-ef2126wm
# 2              Nuevo                NaN  Notebook    N14WCE128
# 3              Nuevo                NaN   IdeaPad            3
# 4              Nuevo                NaN     Smart   XQ3H-S3182
#
#   Capacidad Optane Unidades ópticas Edición del sistema operativo  \
# 0             None             None                          None
# 1              NaN              NaN                          Home
# 2             None             None                          Home
# 3              NaN              NaN                          Home
# 4             None             None                          Home
#
#   Nombre del sistema operativo Versión del sistema operativo  \
# 0                      Windows                            11
# 1                      Windows                            10
# 2                      Windows                            10
# 3                      Windows                            10
# 4                      Windows                            11
#
#   Marca del procesador Línea del procesador Memoria RAM Tipo de memoria RAM  \
# 0                  AMD              Ryzen 7       12 GB                DDR4
# 1                  AMD              Ryzen 5        8 GB                DDR4
# 2                Intel              Celeron        4 GB                None
# 3                Intel              Core i5        8 GB                DDR4
# 4                Intel              Core i3        8 GB                DDR4
#
#   Capacidad del SSD Memoria de video     Peso Con Bluetooth  \
# 0            256 GB             None  1.74 kg            Sí
# 1            256 GB              NaN  1.69 kg            Sí
# 2            128 GB             None   1.5 kg            Sí
# 3            512 GB              NaN   1.6 kg            Sí
# 4            256 GB             None   1850 g            Sí
#
#   Con lector de huella digital Con HDMI Con micrófono Con pantalla táctil  \
# 0                           Sí       Sí            Sí                  Sí
# 1                           No       Sí            Sí                  No
# 2                           No       Sí            Sí                  No
# 3                           No       Sí            Sí                  No
# 4                          NaN       Sí            Sí                  No
#
#   Con USB Con Wi-Fi Relación de aspecto          Color Gama de colores  \
# 0      Sí        Sí                 NaN            NaN             NaN
# 1      Sí        Sí                16:9    Spruce blue        45% NTSC
# 2      Sí        Sí                16:9       Plateado             NaN
# 3      Sí        Sí                16:9  Platinum gray             NaN
# 4      Sí        Sí                16:9       Plateado             NaN
#
#   Profundidad Modelo detallado Tipo de resolución de la pantalla   \
# 0         NaN              NaN                                NaN
# 1     24.2 cm          4J771UA                            Full HD
# 2        3 cm      94N14WCE128                                 HD
# 3      241 mm       81WD00U9US                            Full HD
# 4         NaN              NaN                            Full HD
#
#   Código universal de producto   Altura Incluye lápiz Color principal  \
# 0                          NaN      NaN           NaN             NaN
# 1                 196068804015  1.79 cm            No            Azul
# 2                7798192367744    22 cm            No            Gris
# 3                0196119591499  19.9 mm           NaN        Plateado
# 4                7797678017821      NaN           NaN        Plateado
#
#   Velocidad máxima del procesador Velocidad mínima del procesador  \
# 0                             NaN                             NaN
# 1                           4 GHz                         2.1 GHz
# 2                             NaN                             NaN
# 3                         3.6 GHz                             NaN
# 4                         4.1 GHz                           3 GHz
#
#              MPN Modelo del procesador Velocidad de la memoria RAM  \
# 0            NaN                   NaN                         NaN
# 1        4J771UA                 5500U                    3200 MHz
# 2  7798192367744                 N3350                         NaN
# 3     81WD00U9US                1035G1                    2666 MHz
# 4         XQ3H-8                1115G4                         NaN
#
#   Cantidad de ranuras para la memoria RAM             Software incluidos  \
# 0                                     NaN                            NaN
# 1                                       2  McAfee LiveSafe,Microsoft 365
# 2                                     NaN                            NaN
# 3                                       2                            NaN
# 4                                     NaN                            NaN
#
#       Modos de sonido Cantidad de parlantes Interfaz del SSD  \
# 0                 NaN                   NaN              NaN
# 1              Stereo                     2             PCIe
# 2              Stereo                     2              NaN
# 3  Dolby Audio,Stereo                     2             PCIe
# 4              Stereo                     2              M.2
#
#            Puertos USB Cantidad total de puertos USB Puertos de video  \
# 0                  NaN                           NaN              NaN
# 1  USB-C 3.0,USB-A 3.0                             3             HDMI
# 2                  NaN                             2        Mini-HDMI
# 3              2.0,3.2                             3             HDMI
# 4                 A3.0                             2             HDMI
#
#   Resolución de video de la cámara web  \
# 0                                  NaN
# 1                     1280 px x 720 px
# 2                                  NaN
# 3                                  NaN
# 4                     1280 px x 720 px
#
#   Tipo de resolución de video de la cámara web     Ancho  \
# 0                                          NaN       NaN
# 1                                           HD  35.85 cm
# 2                                          NaN     34 cm
# 3                                          NaN  327.1 mm
# 4                                           HD       NaN
#
#   Con pantalla antirreflejo Con salida para auriculares  \
# 0                       NaN                         NaN
# 1                        Sí                          Sí
# 2                       NaN                          Sí
# 3                        Sí                          Sí
# 4                       NaN                          Sí
#
#   Con lector de tarjeta de memoria Con pad numérico Con pantalla retina  \
# 0                              NaN              NaN                 NaN
# 1                               Sí               Sí                  No
# 2                               Sí               No                  No
# 3                               Sí              NaN                 NaN
# 4                               Sí               Sí                 NaN
#
#   Con cámara web Modelo alfanumérico Tipo de pantalla  \
# 0            NaN                 NaN              NaN
# 1             Sí                 NaN              NaN
# 2             Sí         94N14WCE128              LED
# 3             Sí             14IIL05              LCD
# 4             Sí                 NaN              LED
#
#   Capacidad máxima soportada de la memoria RAM Altura del paquete  \
# 0                                          NaN                NaN
# 1                                          NaN                NaN
# 2                                         4 GB             8.2 cm
# 3                                        12 GB                NaN
# 4                                          NaN             5.8 cm
#
#   Largo del paquete Peso del paquete Ancho del paquete            SKU  \
# 0               NaN              NaN               NaN            NaN
# 1               NaN              NaN               NaN            NaN
# 2           24.6 cm           1760 g           35.4 cm  7798192367744
# 3               NaN              NaN               NaN     81WA00Q7US
# 4           48.6 cm           2640 g           28.2 cm           7248
#
#   Resolución de la imagen fija de la cámara web Con teclado retroiluminado  \
# 0                                           NaN                        NaN
# 1                                           NaN                        NaN
# 2                                         2 Mpx                         No
# 3                                       0.3 Mpx                         No
# 4                                           NaN                        NaN
#
#   Con puerto ethernet Información adicional requerida  \
# 0                 NaN                             NaN
# 1                 NaN                             NaN
# 2                  No                             NaN
# 3                  No                             NaN
# 4                  Sí           Tiene número de serie
#
#   Características del producto Embalaje del envío Canal exclusivo  \
# 0                          NaN                NaN             NaN
# 1                          NaN                NaN             NaN
# 2                          NaN                NaN             NaN
# 3                          NaN                NaN             NaN
# 4       Frágil,Sin vencimiento               Caja             NaN
#
#   Tipo de panel Tipo de resolución Interfaz del disco rígido  GPU  \
# 0           NaN                NaN                       NaN  NaN
# 1           NaN                NaN                       NaN  NaN
# 2           NaN                NaN                       NaN  NaN
# 3           NaN                NaN                       NaN  NaN
# 4           NaN                NaN                       NaN  NaN
#
#   Velocidad del procesador Resolución de la cámara web Accesorios incluidos  \
# 0                      NaN                         NaN                  NaN
# 1                      NaN                         NaN                  NaN
# 2                      NaN                         NaN                  NaN
# 3                      NaN                         NaN                  NaN
# 4                      NaN                         NaN                  NaN
#
#   Tipos de memoria de video Características de las baterías  \
# 0                       NaN                             NaN
# 1                       NaN                             NaN
# 2                       NaN                             NaN
# 3                       NaN                             NaN
# 4                       NaN                             NaN
#
#   Tipo de almacenamiento de datos Capacidad de almacenamiento Es kit  \
# 0                             NaN                         NaN    NaN
# 1                             NaN                         NaN    NaN
# 2                             NaN                         NaN    NaN
# 3                             NaN                         NaN    NaN
# 4                             NaN                         NaN    NaN
#
#   Fuente del producto Disponibilidad de stock Procesador Tags descriptivos  \
# 0                 NaN                     NaN        NaN               NaN
# 1                 NaN                     NaN        NaN               NaN
# 2                 NaN                     NaN        NaN               NaN
# 3                 NaN                     NaN        NaN               NaN
# 4                 NaN                     NaN        NaN               NaN
#
#   Largo Serie Máxima capacidad de RAM Características químicas del producto
# 0   NaN   NaN                     NaN                                   NaN
# 1   NaN   NaN                     NaN                                   NaN
# 2   NaN   NaN                     NaN                                   NaN
# 3   NaN   NaN                     NaN                                   NaN
# 4   NaN   NaN                     NaN                                   NaN

# %%
df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 732 entries, 0 to 731
# Data columns (total 107 columns):
#  #    Column                                         Non-Null Count  Dtype
# ---   ------                                         --------------  -----
#  0    id                                             732 non-null    object
#  1    title                                          732 non-null    object
#  2    price                                          732 non-null    float64
#  3    base_price                                     732 non-null    float64
#  4    permalink                                      732 non-null    object
#  5    Duración de la batería                         330 non-null    object
#  6    Tipo de batería                                667 non-null    object
#  7    Marca                                          732 non-null    object
#  8    Cantidad de núcleos                            686 non-null    object
#  9    Frecuencia de actualización de la pantalla     450 non-null    object
#  10   Resolución de la pantalla                      724 non-null    object
#  11   Tamaño de la pantalla                          727 non-null    object
#  12   Tarjeta gráfica                                639 non-null    object
#  13   Capacidad del disco rígido                     170 non-null    object
#  14   Es 2 en 1                                      611 non-null    object
#  15   Es gamer                                       619 non-null    object
#  16   Es ultrabook                                   593 non-null    object
#  17   Condición del ítem                             732 non-null    object
#  18   Idioma del teclado                             91 non-null     object
#  19   Línea                                          694 non-null    object
#  20   Modelo                                         732 non-null    object
#  21   Capacidad Optane                               35 non-null     object
#  22   Unidades ópticas                               148 non-null    object
#  23   Edición del sistema operativo                  568 non-null    object
#  24   Nombre del sistema operativo                   732 non-null    object
#  25   Versión del sistema operativo                  605 non-null    object
#  26   Marca del procesador                           732 non-null    object
#  27   Línea del procesador                           711 non-null    object
#  28   Memoria RAM                                    732 non-null    object
#  29   Tipo de memoria RAM                            705 non-null    object
#  30   Capacidad del SSD                              674 non-null    object
#  31   Memoria de video                               99 non-null     object
#  32   Peso                                           689 non-null    object
#  33   Con Bluetooth                                  672 non-null    object
#  34   Con lector de huella digital                   323 non-null    object
#  35   Con HDMI                                       656 non-null    object
#  36   Con micrófono                                  622 non-null    object
#  37   Con pantalla táctil                            635 non-null    object
#  38   Con USB                                        670 non-null    object
#  39   Con Wi-Fi                                      668 non-null    object
#  40   Relación de aspecto                            391 non-null    object
#  41   Color                                          222 non-null    object
#  42   Gama de colores                                212 non-null    object
#  43   Profundidad                                    567 non-null    object
#  44   Modelo detallado                               152 non-null    object
#  45   Tipo de resolución de la pantalla              332 non-null    object
#  46   Código universal de producto                   304 non-null    object
#  47   Altura                                         558 non-null    object
#  48   Incluye lápiz                                  207 non-null    object
#  49   Color principal                                223 non-null    object
#  50   Velocidad máxima del procesador                340 non-null    object
#  51   Velocidad mínima del procesador                226 non-null    object
#  52   MPN                                            161 non-null    object
#  53   Modelo del procesador                          424 non-null    object
#  54   Velocidad de la memoria RAM                    285 non-null    object
#  55   Cantidad de ranuras para la memoria RAM        377 non-null    object
#  56   Software incluidos                             104 non-null    object
#  57   Modos de sonido                                478 non-null    object
#  58   Cantidad de parlantes                          440 non-null    object
#  59   Interfaz del SSD                               280 non-null    object
#  60   Puertos USB                                    525 non-null    object
#  61   Cantidad total de puertos USB                  535 non-null    object
#  62   Puertos de video                               540 non-null    object
#  63   Resolución de video de la cámara web           174 non-null    object
#  64   Tipo de resolución de video de la cámara web   244 non-null    object
#  65   Ancho                                          572 non-null    object
#  66   Con pantalla antirreflejo                      355 non-null    object
#  67   Con salida para auriculares                    547 non-null    object
#  68   Con lector de tarjeta de memoria               487 non-null    object
#  69   Con pad numérico                               367 non-null    object
#  70   Con pantalla retina                            227 non-null    object
#  71   Con cámara web                                 628 non-null    object
#  72   Modelo alfanumérico                            188 non-null    object
#  73   Tipo de pantalla                               426 non-null    object
#  74   Capacidad máxima soportada de la memoria RAM   320 non-null    object
#  75   Altura del paquete                             39 non-null     object
#  76   Largo del paquete                              39 non-null     object
#  77   Peso del paquete                               39 non-null     object
#  78   Ancho del paquete                              39 non-null     object
#  79   SKU                                            168 non-null    object
#  80   Resolución de la imagen fija de la cámara web  248 non-null    object
#  81   Con teclado retroiluminado                     304 non-null    object
#  82   Con puerto ethernet                            433 non-null    object
#  83   Información adicional requerida                39 non-null     object
#  84   Características del producto                   76 non-null     object
#  85   Embalaje del envío                             87 non-null     object
#  86   Canal exclusivo                                169 non-null    object
#  87   Tipo de panel                                  147 non-null    object
#  88   Tipo de resolución                             149 non-null    object
#  89   Interfaz del disco rígido                      72 non-null     object
#  90   GPU                                            58 non-null     object
#  91   Velocidad del procesador                       108 non-null    object
#  92   Resolución de la cámara web                    86 non-null     object
#  93   Accesorios incluidos                           27 non-null     object
#  94   Tipos de memoria de video                      29 non-null     object
#  95   Características de las baterías                47 non-null     object
#  96   Tipo de almacenamiento de datos                10 non-null     object
#  97   Capacidad de almacenamiento                    5 non-null      object
#  98   Es kit                                         2 non-null      object
#  99   Fuente del producto                            0 non-null      object
#  100  Disponibilidad de stock                        1 non-null      object
#  101  Procesador                                     3 non-null      object
#  102  Tags descriptivos                              2 non-null      object
#  103  Largo                                          1 non-null      object
#  104  Serie                                          2 non-null      object
#  105  Máxima capacidad de RAM                        1 non-null      object
#  106  Características químicas del producto          1 non-null      object
# dtypes: float64(2), object(105)
# memory usage: 617.6+ KB
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: null_counts is deprecated. Use show_counts instead
#   """Entry point for launching an IPython kernel.

# %%
df.shape
# Out:
# (732, 107)

# %%
df = df[["id", "price", "Marca", "Resolución de la pantalla", "Es gamer", "Velocidad máxima del procesador",
         "Capacidad del SSD", "Memoria RAM", "Velocidad de la memoria RAM", "Línea del procesador", "Marca del procesador",
         "Capacidad del SSD", "Frecuencia de actualización de la pantalla"]]

# %% [markdown]
# Haremos un analisis exploratorio con los siguientes campos para poder determinar cuales usar para las categorias:
# - price
# - marca
# - resolucion
# - es gamer
# - velocidad max del procesador
# - marca
# - linea del procesador
# - memoria ram
# - capacidad del ssd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.price.describe()
# Out:
# count      732.00000
# mean    185562.20898
# std     100917.94351
# min      28500.00000
# 25%     119999.00000
# 50%     169999.00000
# 75%     229999.00000
# max     861385.00000
# Name: price, dtype: float64

# %%
sns.set_theme(style="whitegrid")

plt.figure(figsize=(12,7))
ax = sns.boxplot(x="price", data=df[df["price"] < 1.000000e+07])
ax.set_title("Laptop's Price")
plt.show()

# %%
marcas = df.Marca.value_counts().to_frame()
marcas["condicion"] = marcas.index
marcas.loc[marcas["Marca"] < 100, "condicion"] = "Otro"
marcas = marcas.rename_axis('Marca_Original').reset_index()
marcas.columns = ["Marca_Original", "Cantidad", "Marca_Nueva"]
marcas.tail()

del marcas["Cantidad"]

# %%
df = df.merge(marcas,
         how = "left",
         left_on = "Marca",
         right_on = "Marca_Original")

# %%
df.head()
# Out:
#               id        price   Marca Resolución de la pantalla Es gamer  \
# 0  MLA1129251702 164899.00000      HP          1366 px x 768 px       Sí
# 1  MLA1147028688 129499.00000      HP         1920 px x 1080 px       No
# 2  MLA1110784573  66999.00000  Noblex          1366 px x 768 px       No
# 3  MLA1149134293 138100.00000  Lenovo         1920 px x 1080 px      NaN
# 4  MLA1140410405 129999.00000     EXO         1920 px x 1080 px       No
#
#   Velocidad máxima del procesador Capacidad del SSD Memoria RAM  \
# 0                             NaN            256 GB       12 GB
# 1                           4 GHz            256 GB        8 GB
# 2                             NaN            128 GB        4 GB
# 3                         3.6 GHz            512 GB        8 GB
# 4                         4.1 GHz            256 GB        8 GB
#
#   Velocidad de la memoria RAM Línea del procesador Marca del procesador  \
# 0                         NaN              Ryzen 7                  AMD
# 1                    3200 MHz              Ryzen 5                  AMD
# 2                         NaN              Celeron                Intel
# 3                    2666 MHz              Core i5                Intel
# 4                         NaN              Core i3                Intel
#
#   Capacidad del SSD Frecuencia de actualización de la pantalla Marca_Original  \
# 0            256 GB                                       None             HP
# 1            256 GB                                        NaN             HP
# 2            128 GB                                      60 Hz         Noblex
# 3            512 GB                                        NaN         Lenovo
# 4            256 GB                                      60 Hz            EXO
#
#   Marca_Nueva
# 0          HP
# 1          HP
# 2        Otro
# 3      Lenovo
# 4        Otro

# %%
del df["Marca_Original"], df["Marca"]
df.rename(columns = {"Marca_Nueva" : "Marca"}, inplace = True)

# %%
df.head()
# Out:
#               id        price Resolución de la pantalla Es gamer  \
# 0  MLA1129251702 164899.00000          1366 px x 768 px       Sí
# 1  MLA1147028688 129499.00000         1920 px x 1080 px       No
# 2  MLA1110784573  66999.00000          1366 px x 768 px       No
# 3  MLA1149134293 138100.00000         1920 px x 1080 px      NaN
# 4  MLA1140410405 129999.00000         1920 px x 1080 px       No
#
#   Velocidad máxima del procesador Capacidad del SSD Memoria RAM  \
# 0                             NaN            256 GB       12 GB
# 1                           4 GHz            256 GB        8 GB
# 2                             NaN            128 GB        4 GB
# 3                         3.6 GHz            512 GB        8 GB
# 4                         4.1 GHz            256 GB        8 GB
#
#   Velocidad de la memoria RAM Línea del procesador Marca del procesador  \
# 0                         NaN              Ryzen 7                  AMD
# 1                    3200 MHz              Ryzen 5                  AMD
# 2                         NaN              Celeron                Intel
# 3                    2666 MHz              Core i5                Intel
# 4                         NaN              Core i3                Intel
#
#   Capacidad del SSD Frecuencia de actualización de la pantalla   Marca
# 0            256 GB                                       None      HP
# 1            256 GB                                        NaN      HP
# 2            128 GB                                      60 Hz    Otro
# 3            512 GB                                        NaN  Lenovo
# 4            256 GB                                      60 Hz    Otro

# %%
sns.set_theme(style="whitegrid")

plt.figure(figsize=(12,7))
ax = sns.boxplot(x="price", data=df[df["price"] < 1.000000e+07], y = "Marca")
ax.set_title("Laptop's Price")
plt.show()

# %%
plt.figure(figsize=(12,7))
ax = sns.boxplot(x="price", data=df[df["price"] < 1.000000e+07], y = "Es gamer")
ax.set_title("Laptop's Price")
plt.show()

# %% [markdown]
# ## Procesador

# %%
df["Línea del procesador"].value_counts().to_frame().head()
# Out:
#          Línea del procesador
# Core i5                   189
# Core i7                   111
# Core i3                   100
# Celeron                    81
# Ryzen 5                    59

# %%
df["Línea del procesador"].nunique()
# Out:
# 82

# %%
condic_i3 = df["Línea del procesador"].str.lower().str.contains("i3", na=False)
condic_i5 = df["Línea del procesador"].str.lower().str.contains("i5", na=False)
condic_i7 = df["Línea del procesador"].str.lower().str.contains("i7", na=False)
condic_i9 = df["Línea del procesador"].str.lower().str.contains("i9", na=False)

df["linea_procesador"] = df["Línea del procesador"].copy()
df.loc[condic_i3, "linea_procesador"] = "Core i3"
df.loc[condic_i5, "linea_procesador"] = "Core i5"
df.loc[condic_i7, "linea_procesador"] = "Core i7"
df.loc[condic_i9, "linea_procesador"] = "Core i9"

# %%
cond_ryzen = df["Línea del procesador"].str.lower().str.contains("ryzen", na=False)
condic_r3 = df["Línea del procesador"].str.lower().str.contains("3", na=False)
condic_r5 = df["Línea del procesador"].str.lower().str.contains("5", na=False)
condic_r7 = df["Línea del procesador"].str.lower().str.contains("7", na=False)
condic_r9 = df["Línea del procesador"].str.lower().str.contains("9", na=False)


df.loc[condic_r3 & cond_ryzen, "linea_procesador"] = "Ryzen 3"
df.loc[condic_r5& cond_ryzen, "linea_procesador"] = "Ryzen 5"
df.loc[condic_r7& cond_ryzen, "linea_procesador"] = "Ryzen 7"
df.loc[condic_r9& cond_ryzen, "linea_procesador"] = "Ryzen 9"

# %%
condic_a6 = df["Línea del procesador"].str.lower().str.contains("a6", na=False)
condic_a8 = df["Línea del procesador"].str.lower().str.contains("a8", na=False)
condic_a10 = df["Línea del procesador"].str.lower().str.contains("a10", na=False)
condic_a12 = df["Línea del procesador"].str.lower().str.contains("a12", na=False)


df.loc[condic_a6, "linea_procesador"] = "AMD A6"
df.loc[condic_a8, "linea_procesador"] = "AMD A8"
df.loc[condic_a10, "linea_procesador"] = "AMD A10"
df.loc[condic_a12, "linea_procesador"] = "AMD A12"

# %%
cond_celeron = df["Línea del procesador"].str.lower().str.contains("celeron", na=False)
df.loc[cond_celeron, "linea_procesador"] = "Celeron"

# %%
cond_pentium = df["Línea del procesador"].str.lower().str.contains("pentium", na=False)
df.loc[cond_pentium, "linea_procesador"] = "Pentium"

# %%
cond_athlon = df["Línea del procesador"].str.lower().str.contains("athlon", na=False)
df.loc[cond_athlon, "linea_procesador"] = "Athlon"

# %%
cond_sempron = df["Línea del procesador"].str.lower().str.contains("sempron", na=False)
df.loc[cond_sempron, "linea_procesador"] = "Sempron"

# %%
cond_m1 = df["Línea del procesador"].str.lower().str.contains("m1", na=False)
df.loc[cond_m1, "linea_procesador"] = "M1"

cond_m2 = df["Línea del procesador"].str.lower().str.contains("m2", na=False)
df.loc[cond_m2, "linea_procesador"] = "M2"

# %%
df["linea_procesador"].nunique()
# Out:
# 21

# %%
proc = df.linea_procesador.value_counts().to_frame()
proc["condicion"] = proc.index
proc.loc[proc["linea_procesador"] < 9, "condicion"] = "Otro"
proc = proc.rename_axis('linea_procesador_Original').reset_index()
proc.columns = ["linea_procesador_Original", "Cantidad", "linea_procesador_Nueva"]
proc.tail()
# Out:
#            linea_procesador_Original  Cantidad linea_procesador_Nueva
# 16                   CORE I 7 1165G7         1                   Otro
# 17  Intel Apollo N3350 (Max. 2.4GHz)         1                   Otro
# 18                         A4-Series         1                   Otro
# 19                             N4020         1                   Otro
# 20                         A9-Series         1                   Otro

# %%
del proc["Cantidad"]

# %%
df = df.merge(proc,
         how = "left",
         left_on = "linea_procesador",
         right_on = "linea_procesador_Original")
df.head()
# Out:
#               id        price Resolución de la pantalla Es gamer  \
# 0  MLA1129251702 164899.00000          1366 px x 768 px       Sí
# 1  MLA1147028688 129499.00000         1920 px x 1080 px       No
# 2  MLA1110784573  66999.00000          1366 px x 768 px       No
# 3  MLA1149134293 138100.00000         1920 px x 1080 px      NaN
# 4  MLA1140410405 129999.00000         1920 px x 1080 px       No
#
#   Velocidad máxima del procesador Capacidad del SSD Memoria RAM  \
# 0                             NaN            256 GB       12 GB
# 1                           4 GHz            256 GB        8 GB
# 2                             NaN            128 GB        4 GB
# 3                         3.6 GHz            512 GB        8 GB
# 4                         4.1 GHz            256 GB        8 GB
#
#   Velocidad de la memoria RAM Línea del procesador Marca del procesador  \
# 0                         NaN              Ryzen 7                  AMD
# 1                    3200 MHz              Ryzen 5                  AMD
# 2                         NaN              Celeron                Intel
# 3                    2666 MHz              Core i5                Intel
# 4                         NaN              Core i3                Intel
#
#   Capacidad del SSD Frecuencia de actualización de la pantalla   Marca  \
# 0            256 GB                                       None      HP
# 1            256 GB                                        NaN      HP
# 2            128 GB                                      60 Hz    Otro
# 3            512 GB                                        NaN  Lenovo
# 4            256 GB                                      60 Hz    Otro
#
#   linea_procesador linea_procesador_Original linea_procesador_Nueva
# 0          Ryzen 7                   Ryzen 7                Ryzen 7
# 1          Ryzen 5                   Ryzen 5                Ryzen 5
# 2          Celeron                   Celeron                Celeron
# 3          Core i5                   Core i5                Core i5
# 4          Core i3                   Core i3                Core i3

# %%
del df["linea_procesador"], df["linea_procesador_Original"], df["Línea del procesador"]

df = df.rename(columns = {"linea_procesador_Nueva"  : "linea_procesador"})
df.head()
# Out:
#               id        price Resolución de la pantalla Es gamer  \
# 0  MLA1129251702 164899.00000          1366 px x 768 px       Sí
# 1  MLA1147028688 129499.00000         1920 px x 1080 px       No
# 2  MLA1110784573  66999.00000          1366 px x 768 px       No
# 3  MLA1149134293 138100.00000         1920 px x 1080 px      NaN
# 4  MLA1140410405 129999.00000         1920 px x 1080 px       No
#
#   Velocidad máxima del procesador Capacidad del SSD Memoria RAM  \
# 0                             NaN            256 GB       12 GB
# 1                           4 GHz            256 GB        8 GB
# 2                             NaN            128 GB        4 GB
# 3                         3.6 GHz            512 GB        8 GB
# 4                         4.1 GHz            256 GB        8 GB
#
#   Velocidad de la memoria RAM Marca del procesador Capacidad del SSD  \
# 0                         NaN                  AMD            256 GB
# 1                    3200 MHz                  AMD            256 GB
# 2                         NaN                Intel            128 GB
# 3                    2666 MHz                Intel            512 GB
# 4                         NaN                Intel            256 GB
#
#   Frecuencia de actualización de la pantalla   Marca linea_procesador
# 0                                       None      HP          Ryzen 7
# 1                                        NaN      HP          Ryzen 5
# 2                                      60 Hz    Otro          Celeron
# 3                                        NaN  Lenovo          Core i5
# 4                                      60 Hz    Otro          Core i3

# %%
df[['Capacidad RAM', 'Medida_RAM']] = df["Memoria RAM"].str.split(' ', 1, expand=True)

# %%
cond_ram_mb = (df["Medida_RAM"].str.lower() == "mb")
df.loc[cond_ram_mb, "Capacidad RAM"] = df['Capacidad RAM'].fillna(-1).astype(float, errors = "ignore").astype(int) / 1000
df.loc[cond_ram_mb, "Medida_RAM"] = "GB"

# %%
cond_ram_kb = (df["Medida_RAM"].str.lower() == "kb")
df.loc[cond_ram_kb, "Capacidad RAM"] = df['Capacidad RAM'].fillna(-1).astype(float, errors = "ignore").astype(int) / 1000000
df.loc[cond_ram_kb, "Medida_RAM"] = "GB"

# %%
df['Medida_RAM'].value_counts()
# Out:
# GB    732
# Name: Medida_RAM, dtype: int64

# %%
df["Capacidad RAM"] = df["Capacidad RAM"].fillna(-1).astype(float)

# %%
sns.set_theme(style="whitegrid")

plt.figure(figsize=(12,7))
ax = sns.boxplot(x="Capacidad RAM", data=df[df["Capacidad RAM"] < 129])
ax.set_title("Laptop's RAM")
plt.show()

# %%
df["Capacidad RAM"].describe()
# Out:
# count   732.00000
# mean     10.40437
# std       7.39286
# min       2.00000
# 25%       8.00000
# 50%       8.00000
# 75%      12.00000
# max      64.00000
# Name: Capacidad RAM, dtype: float64

# %%
sns.set_theme(style="whitegrid")

plt.figure(figsize=(12,7))
ax = sns.boxplot(x="Capacidad RAM", data=df[df["Capacidad RAM"] < 129], y = "Marca")
ax.set_title("Laptop's RAM")
plt.show()

# %% [markdown]
# ## Velocidad max del procesador

# %%
df["Velocidad máxima del procesador"].value_counts()
# Out:
# 4.2 GHz     70
# 4.1 GHz     50
# 2.8 GHz     27
# 3.4 GHz     23
# 3.5 GHz     22
# 4 GHz       21
# 4.7 GHz     19
# 2.6 GHz     15
# 3.9 GHz     13
# 3.1 GHz     12
# 3.6 GHz     12
# 3.7 GHz      8
# 4.9 GHz      7
# 3.22 GHz     7
# 4.4 GHz      6
# 4.5 GHz      6
# 2.4 GHz      4
# 1.9 GHz      3
# 4.8 GHz      3
# 2.3 GHz      2
# 4.3 GHz      2
# 3.2 GHz      2
# 2.7 GHz      2
# 3.3 GHz      1
# 2.9 GHz      1
# 1.92 GHz     1
# 4.6 GHz      1
# Name: Velocidad máxima del procesador, dtype: int64

# %%
df[['velocidad_max_procesador', 'medida_vel_procesador']] = df["Velocidad máxima del procesador"].str.split(' ', 1, expand=True)

# %%
df.medida_vel_procesador.value_counts()
# Out:
# GHz    340
# Name: medida_vel_procesador, dtype: int64

# %%
cond_ram_MHz = (df["medida_vel_procesador"].str.lower() == "mhz")
df.loc[cond_ram_MHz, "velocidad_max_procesador"] = df['velocidad_max_procesador'].fillna(-1).astype(float, errors = "ignore").astype(int) / 1000
df.loc[cond_ram_MHz, "medida_vel_procesador"] = "GHz"

# %%
cond_ram_Hz = (df["medida_vel_procesador"].str.lower() == "hz")
df.loc[cond_ram_Hz, "velocidad_max_procesador"] = df['velocidad_max_procesador'].fillna(-1).astype(float, errors = "ignore").astype(int) / 1000000000
df.loc[cond_ram_Hz, "medida_vel_procesador"] = "GHz"

# %%
df["velocidad_max_procesador"] = df["velocidad_max_procesador"].astype(float)

# %%
sns.set_theme(style="whitegrid")

plt.figure(figsize=(12,7))
ax = sns.boxplot(x="velocidad_max_procesador", data=df[df["velocidad_max_procesador"] < 40])
ax.set_title("Laptop's Vel procesador")
plt.show()

# %%
df["velocidad_max_procesador"].describe()
# Out:
# count   340.00000
# mean      3.76606
# std       0.65025
# min       1.90000
# 25%       3.40000
# 50%       4.00000
# 75%       4.20000
# max       4.90000
# Name: velocidad_max_procesador, dtype: float64

# %% [markdown]
# ##Etiquetado

# %%
df["Es gamer"].value_counts()
# Out:
# No    509
# Sí    110
# Name: Es gamer, dtype: int64

# %%
df["velocidad_max_procesador"].isna().sum()
# Out:
# 392

# %%
cond_gamer = (df["Es gamer"] == "Sí")
cond_mac_MSI = df["Marca"].isin(["MSI","Apple"])
cond_ram = df["Capacidad RAM"] > 12
cond_procesador = df["linea_procesador"].isin(["Core i7", "Core i9", "Ryzen 7", "Ryzen 9"])

# %%
df["label"] = "Estandar Tradicional"
df.loc[cond_gamer, "label"] = "Gamer"
df.loc[df["Es gamer"].isna(), "label"] = ""
df.loc[cond_mac_MSI, "label"] = "Estandar Premium"
df.loc[cond_ram, "label"] = "Estandar Premium"
df.loc[df["Capacidad RAM"] == -1, "label"] = ""
df.loc[df["linea_procesador"].isna(), "label"] = ""
df.loc[cond_procesador, "label"] = "Estandar Premium"

# %%
df.label.value_counts()
# Out:
# Estandar Tradicional    338
# Estandar Premium        241
#                         105
# Gamer                    48
# Name: label, dtype: int64

# %%
df.head()
# Out:
#               id        price Resolución de la pantalla Es gamer  \
# 0  MLA1129251702 164899.00000          1366 px x 768 px       Sí
# 1  MLA1147028688 129499.00000         1920 px x 1080 px       No
# 2  MLA1110784573  66999.00000          1366 px x 768 px       No
# 3  MLA1149134293 138100.00000         1920 px x 1080 px      NaN
# 4  MLA1140410405 129999.00000         1920 px x 1080 px       No
#
#   Velocidad máxima del procesador Capacidad del SSD Memoria RAM  \
# 0                             NaN            256 GB       12 GB
# 1                           4 GHz            256 GB        8 GB
# 2                             NaN            128 GB        4 GB
# 3                         3.6 GHz            512 GB        8 GB
# 4                         4.1 GHz            256 GB        8 GB
#
#   Velocidad de la memoria RAM Marca del procesador Capacidad del SSD  \
# 0                         NaN                  AMD            256 GB
# 1                    3200 MHz                  AMD            256 GB
# 2                         NaN                Intel            128 GB
# 3                    2666 MHz                Intel            512 GB
# 4                         NaN                Intel            256 GB
#
#   Frecuencia de actualización de la pantalla   Marca linea_procesador  \
# 0                                       None      HP          Ryzen 7
# 1                                        NaN      HP          Ryzen 5
# 2                                      60 Hz    Otro          Celeron
# 3                                        NaN  Lenovo          Core i5
# 4                                      60 Hz    Otro          Core i3
#
#    Capacidad RAM Medida_RAM  velocidad_max_procesador medida_vel_procesador  \
# 0       12.00000         GB                       NaN                   NaN
# 1        8.00000         GB                   4.00000                   GHz
# 2        4.00000         GB                       NaN                   NaN
# 3        8.00000         GB                   3.60000                   GHz
# 4        8.00000         GB                   4.10000                   GHz
#
#                   label
# 0      Estandar Premium
# 1  Estandar Tradicional
# 2  Estandar Tradicional
# 3
# 4  Estandar Tradicional

# %%
to_label = ( df.label == "")
to_train = ( ( df.label != "") & ( df.label.notna()))

# %%
df[to_label].shape
# Out:
# (105, 18)

# %%
df[to_train].shape
# Out:
# (627, 18)

# %%
df[to_label].to_csv("/content/drive/MyDrive/Austral/Maestria/Redes/Trabajo Final Redes/ML_dataset/to_label.csv", index = False)
df[to_train].to_csv("/content/drive/MyDrive/Austral/Maestria/Redes/Trabajo Final Redes/ML_dataset/to_train.csv", index = False)

# %%
labels = df[["id", "label"]]
labels.head()
path_images = "/content/drive/MyDrive/Austral/Maestria/Redes/Trabajo Final Redes/imagenes/MLA1652/"
labels["path"] = path_images + "categ-MLA1652_itemid-" + df.id.copy() + ".jpg"
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
lista = []
for file in os.listdir(path_images):
  lista.append(file)

# %%
df_fotos = pd.DataFrame(lista)
df_fotos.columns = ["0"]
df_fotos["path_real"] = path_images + + df_fotos["0"].copy()
del df_fotos["0"]
df_fotos.head()
# Out:
#                                            path_real
# 0  /content/drive/MyDrive/Austral/Maestria/Redes/...
# 1  /content/drive/MyDrive/Austral/Maestria/Redes/...
# 2  /content/drive/MyDrive/Austral/Maestria/Redes/...
# 3  /content/drive/MyDrive/Austral/Maestria/Redes/...
# 4  /content/drive/MyDrive/Austral/Maestria/Redes/...

# %%
labels.head()
# Out:
#               id                 label  \
# 0  MLA1129251702      Estandar Premium
# 1  MLA1147028688  Estandar Tradicional
# 2  MLA1110784573  Estandar Tradicional
# 3  MLA1149134293
# 4  MLA1140410405  Estandar Tradicional
#
#                                                 path
# 0  /content/drive/MyDrive/Austral/Maestria/Redes/...
# 1  /content/drive/MyDrive/Austral/Maestria/Redes/...
# 2  /content/drive/MyDrive/Austral/Maestria/Redes/...
# 3  /content/drive/MyDrive/Austral/Maestria/Redes/...
# 4  /content/drive/MyDrive/Austral/Maestria/Redes/...

# %%
labels.shape
# Out:
# (732, 3)

# %%
labels.path.nunique()
# Out:
# 724

# %%
df_fotos.shape
# Out:
# (9999, 1)

# %%
df_fotos.path_real.nunique()
# Out:
# 9999

# %%
result = labels.merge(df_fotos,
             how = "left",
             left_on = "path",
             right_on = "path_real")
del result["path"], result["id"]

# %%
result.head()
# Out:
#                   label                                          path_real
# 0      Estandar Premium                                                NaN
# 1  Estandar Tradicional                                                NaN
# 2  Estandar Tradicional                                                NaN
# 3                                                                      NaN
# 4  Estandar Tradicional  /content/drive/MyDrive/Austral/Maestria/Redes/...

# %%
result["path_real"] = result["path_real"].str.split("/").str[10]
result["dummy"] = 1

# %%
result.head()
# Out:
#                   label                               path_real  dummy
# 0      Estandar Premium                                     NaN      1
# 1  Estandar Tradicional                                     NaN      1
# 2  Estandar Tradicional                                     NaN      1
# 3                                                           NaN      1
# 4  Estandar Tradicional  categ-MLA1652_itemid-MLA1140410405.jpg      1

# %%
del result["dummy"]

# %% [markdown]
# {"Estandar Tradicional" : 1,
#                "Estandar Premium" : 2,
#                "Gamer" : 3}

# %%
result["numeric_label"] = np.where(result["label"] == "Estandar Tradicional", 1 ,
                                   np.where(result["label"] == "Estandar Premium" ,2 ,
                                            np.where(result["label"] == "Gamer" ,3 , np.NaN)
                                  ))
                                  
del result["label"]

# %%
(result.numeric_label == 1).sum()
# Out:
# 338

# %%
result.numeric_label.isna().sum()
# Out:
# 105

# %%
to_label_new = ( (result.numeric_label.isna()) & (result.path_real.notna()) )
to_train_new = ( (result.numeric_label != "") & (result.numeric_label.notna())  & (result.path_real.notna()) & (result.path_real != ""))

# %%
result[to_label_new].head()
# Out:
#                                   path_real  numeric_label
# 7    categ-MLA1652_itemid-MLA1135443731.jpg            NaN
# 36   categ-MLA1652_itemid-MLA1143705696.jpg            NaN
# 82   categ-MLA1652_itemid-MLA1135594941.jpg            NaN
# 93   categ-MLA1652_itemid-MLA1121132117.jpg            NaN
# 117  categ-MLA1652_itemid-MLA1101075408.jpg            NaN

# %%
result[to_label_new].shape
# Out:
# (29, 2)

# %%
result[to_train_new].head()
# Out:
#                                  path_real  numeric_label
# 4   categ-MLA1652_itemid-MLA1140410405.jpg        1.00000
# 8   categ-MLA1652_itemid-MLA1136594401.jpg        1.00000
# 11  categ-MLA1652_itemid-MLA1138721902.jpg        1.00000
# 14  categ-MLA1652_itemid-MLA1141953786.jpg        1.00000
# 22  categ-MLA1652_itemid-MLA1141999385.jpg        1.00000

# %%
result[to_train_new].shape
# Out:
# (295, 2)

# %%
result[to_train_new].to_csv("/content/drive/MyDrive/Austral/Maestria/Redes/Trabajo Final Redes/to_train.csv", index = False)
result[to_label_new].to_csv(path + "to_label.csv", index = False)
